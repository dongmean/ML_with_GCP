# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plot
import numpy as np
import google.datalab.bigquery as bq
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq query --name os_stat
# SELECT time, cpu_usage, max_cpu_usage, free_memory, min_free_memory, total_memory, (total_memory - free_memory)/total_memory as use_memory_rate
# FROM `exem-191100.ods_im5.xapm_db_os_stat`
# WHERE db_id = 6
# ORDER BY time
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query os_stat --count 200000
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_jw4aw1pe_6R1bfwCXW6saXrbELiy

# %% [markdown]
# # os_stat table에는 있는데, stat table에는 없는 시간들..

# %%
# %%bq query --name os_stat_only
# SELECT time, cpu_usage, max_cpu_usage, free_memory, min_free_memory, total_memory, (total_memory - free_memory)/total_memory as use_memory_rate
# FROM `exem-191100.ods_im5.xapm_db_os_stat` as t_os_stat
# WHERE db_id = 6 and NOT EXISTS(
#   SELECT time, stat_id, value
#   FROM `exem-191100.ods_im5.xapm_db_stat` as t_stat
#   WHERE db_id = 6 and EXISTS(
#     SELECT stat_id
#     FROM(
#       SELECT stat_id, MAX(value) as max_value, MIN(value) as min_value
#       FROM `exem-191100.ods_im5.xapm_db_stat`
#       WHERE db_id = 6
#       GROUP BY stat_id
#       HAVING max_value <> 0  and min_value <> 0
#       ORDER BY stat_id) as t_nonzero
#     WHERE t_stat.stat_id = t_nonzero.stat_id
#     ) and stat_id<687
#       and t_os_stat.time = t_stat.time
#   )
# ORDER BY time
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query os_stat_only --count 200000
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_9ConVEibhNymE90JTZI2V3o_O9OV

# %% [markdown]
# # stat table에는 있는데, os_stat table에는 없는 시간들..

# %%
# %%bq query --name stat_only
# SELECT time, COUNT(stat_id)
# FROM `exem-191100.ods_im5.xapm_db_stat` as t_stat
# WHERE db_id = 6 and NOT EXISTS(
#   SELECT time
#   FROM `exem-191100.ods_im5.xapm_db_os_stat` as t_os_stat
#   WHERE db_id = 6 and t_stat.time = t_os_stat.time
#   )
#   and EXISTS(
#     SELECT stat_id
#     FROM(
#       SELECT stat_id, MAX(value) as max_value, MIN(value) as min_value
#       FROM `exem-191100.ods_im5.xapm_db_stat`
#       WHERE db_id = 6
#       GROUP BY stat_id
#       HAVING max_value <> 0  and min_value <> 0
#       ORDER BY stat_id) as t_nonzero
#     WHERE t_stat.stat_id = t_nonzero.stat_id
#     )
#   and stat_id<687
# GROUP BY time
# ORDER BY time
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query stat_only
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_wAEKBRRn83ydVW45BDno8Cv7RhVO

# %% [markdown]
# # timestamp 의 빵구를 찾기위해서 시작시간 ~ 끝시간 까지의 시간 테이블을 Dataframe을 이용하여 만들자

# %% [markdown]
# ## os_stat table의 time 시작과 끝

# %%
# %%bq query --name os_stat_unix_second
# SELECT UNIX_SECONDS(time) as unix_second, cpu_usage, max_cpu_usage, free_memory, min_free_memory, total_memory, (total_memory - free_memory)/total_memory as use_memory_rate
# FROM `exem-191100.ods_im5.xapm_db_os_stat`
# WHERE db_id = 6
# ORDER BY time
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query os_stat_unix_second --count 200000
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_wGTpmqXalUxFYu4MBHlyt6dq5iiq

# %%
os_stat_unix_second_sql = 'SELECT UNIX_SECONDS(time) as unix_second FROM `exem-191100.ods_im5.xapm_db_os_stat` WHERE db_id = 6 ORDER BY time'

os_stat_unix_second_query = bq.Query(os_stat_unix_second_sql)

os_stat_unix_second_df = os_stat_unix_second_query.execute(output_options = bq.QueryOutput.dataframe()).result()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
print(os_stat_unix_second_df.head(10))
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
#    unix_second
# 0   1509721200
# 1   1509721260
# 2   1509721320
# 3   1509721380
# 4   1509721440
# 5   1509721500
# 6   1509721560
# 7   1509721620
# 8   1509721680
# 9   1509721740

# %%
# %%bq query --name os_stat_unix_second_descending
# SELECT UNIX_SECONDS(time) as unix_second, cpu_usage, max_cpu_usage, free_memory, min_free_memory, total_memory, (total_memory - free_memory)/total_memory as use_memory_rate
# FROM `exem-191100.ods_im5.xapm_db_os_stat`
# WHERE db_id = 6
# ORDER BY time DESC
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query os_stat_unix_second_descending --count 200000
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_Uifrw2KkaYCGv70fG0Sym6gyLCKa

# %% [markdown]
# ## stat table의 time 시작과 끝

# %%
# %%bq query --name stat_unix_second
# SELECT UNIX_SECONDS(time) as unix_second, stat_id, value
# FROM `exem-191100.ods_im5.xapm_db_stat`
# WHERE db_id = 6
# GROUP BY time
# ORDER BY time
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query stat_unix_second
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_nsU748VPzfigRDljIZNDeb056jwz

# %%
# test 용

# %%bq query --name stat_unix_second_test
SELECT UNIX_SECONDS(time) as unix_second, COUNT(stat_id) as count
FROM `exem-191100.ods_im5.xapm_db_stat`
WHERE db_id = 6
GROUP BY time
HAVING count <> 34
ORDER BY time
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query stat_unix_second_test
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_m0If5ZQyUF_bPWzWejtOeTK2FK75

# %%
stat_unix_second_sql = 'SELECT UNIX_SECONDS(time) as unix_second FROM `exem-191100.ods_im5.xapm_db_stat` WHERE db_id = 6 GROUP BY time ORDER BY time'

stat_unix_second_query = bq.Query(stat_unix_second_sql)

stat_unix_second_df = stat_unix_second_query.execute(output_options = bq.QueryOutput.dataframe()).result()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
print(stat_unix_second_df.head(10))
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
#    unix_second
# 0   1509721200
# 1   1509721260
# 2   1509721320
# 3   1509721380
# 4   1509721440
# 5   1509721500
# 6   1509721560
# 7   1509721620
# 8   1509721680
# 9   1509721740

# %%
# %%bq query --name stat_unix_second_descending
# SELECT UNIX_SECONDS(time) as unix_second
# FROM `exem-191100.ods_im5.xapm_db_stat`
# WHERE db_id = 6
# GROUP BY time
# ORDER BY time DESC
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query stat_unix_second_descending --count 1000
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_QqeRydHFLpf7h46L8VOfdMqfz8pG

# %% [markdown]
# ## 맨 뒤의 2개의 timestamp는 stat table에만 있음을 알 수 있다. 시간은 unix_second를 기준으로 1,509,721,200 ~ 1,512,386,340 까지로 하면 좋을것 같다
# ''
#
# ## 이제 두 테이블에 모두 없는 빵꾸가 있는지 알아보자
#
# ''
#
# - 데이터 프레임을 sql로 변환시키니깐 데이터가 하나도 안들어갔다, 왜 때문?

# %%
timerange_df = pd.DataFrame(columns=['A'])

for i in range(1509721200, 1512386340):
  if(i%60 == 0):
    timerange_df = timerange_df.append({'A':i}, ignore_index=True)
  
print(timerange_df.head(10))
print(timerange_df.shape[0])
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
#               A
# 0  1.509721e+09
# 1  1.509721e+09
# 2  1.509721e+09
# 3  1.509721e+09
# 4  1.509721e+09
# 5  1.509722e+09
# 6  1.509722e+09
# 7  1.509722e+09
# 8  1.509722e+09
# 9  1.509722e+09
# 44419

# %%
empty_start_time = 0
empty_end_time = 0
prev = 1509721140
sum = 0

for i in range(stat_unix_second_df.shape[0]):
  now = stat_unix_second_df["unix_second"][i]
  if now-prev != 60:
    empty_start_time = prev
    empty_end_time = now
    print(empty_start_time, empty_end_time)
    sum += ( (empty_end_time-empty_start_time)/60 - 1)
  prev = stat_unix_second_df["unix_second"][i]
  
print(sum)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# (1510218780, 1510218900)
# (1510633920, 1510634340)
# (1510747320, 1510747440)
# (1510804380, 1510804560)
# (1510828560, 1510828980)
# (1510842480, 1510842900)
# (1511240220, 1511240400)
# (1511267220, 1511267460)
# (1511409600, 1511409720)
# (1511409960, 1511410380)
# (1511410500, 1511410620)
# (1511410620, 1511410980)
# (1511411040, 1511411220)
# (1511412300, 1511412420)
# (1511412720, 1511412840)
# (1511412960, 1511413260)
# (1511413500, 1511413620)
# (1511415360, 1511415540)
# (1511415540, 1511415660)
# (1511416140, 1511416260)
# (1511416620, 1511416800)
# (1511417820, 1511418900)
# (1511421540, 1511421660)
# (1511421660, 1511423700)
# (1511436360, 1511436480)
# (1511506380, 1511506560)
# (1511510400, 1511510520)
# (1511511240, 1511511360)
# (1511881740, 1511881860)
# (1511883120, 1511883240)
# (1511883420, 1511883540)
# 114

# %%
os_stat_sql = 'SELECT time, cpu_usage, max_cpu_usage, free_memory, min_free_memory, total_memory, (total_memory - free_memory)/total_memory as use_memory_rate FROM `exem-191100.ods_im5.xapm_db_os_stat` WHERE db_id = 6 ORDER BY time'

os_stat_query = bq.Query(os_stat_sql)

os_stat_df = os_stat_query.execute(output_options = bq.QueryOutput.dataframe()).result()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
os_stat_df.head(20)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
#                   time  cpu_usage  max_cpu_usage  free_memory  \
# 0  2017-11-03 15:00:00       5244           6670       246592
# 1  2017-11-03 15:01:00       5201           5720       246007
# 2  2017-11-03 15:02:00       5168           5460       245579
# 3  2017-11-03 15:03:00       5157           5330       245377
# 4  2017-11-03 15:04:00       5263           5610       242621
# 5  2017-11-03 15:05:00       5220           5600       244343
# 6  2017-11-03 15:06:00       5218           5530       243530
# 7  2017-11-03 15:07:00       5274           5630       243200
# 8  2017-11-03 15:08:00       5142           5430       242762
# 9  2017-11-03 15:09:00       5260           5520       242303
# 10 2017-11-03 15:10:00       5197           5620       245299
# 11 2017-11-03 15:11:00       5278           5790       245057
# 12 2017-11-03 15:12:00       5162           5480       244443
# 13 2017-11-03 15:13:00       5120           5450       244207
# 14 2017-11-03 15:14:00       5099           5470       241388
# 15 2017-11-03 15:15:00       5182           5490       243640
# 16 2017-11-03 15:16:00       5133           5490       243390
# 17 2017-11-03 15:17:00       5192           5500       243131
# 18 2017-11-03 15:18:00       5169           5660       242732
# 19 2017-11-03 15:19:00       5239           5540       242410
#
#     min_free_memory  total_memory  use_memory_rate
# 0            241860       6117496         0.959691
# 1            241844       6117496         0.959786
# 2            241372       6117496         0.959856
# 3            241372       6117496         0.959889
# 4            240992       6117496         0.960340
# 5            240256       6117496         0.960058
# 6            239876       6117496         0.960191
# 7            239636       6117496         0.960245
# 8            239132       6117496         0.960317
# 9            238636       6117496         0.960392
# 10           241728       6117496         0.959902
# 11           241488       6117496         0.959942
# 12           240124       6117496         0.960042
# 13           240132       6117496         0.960081
# 14           239512       6117496         0.960541
# 15           239636       6117496         0.960173
# 16           239876       6117496         0.960214
# 17           239628       6117496         0.960256
# 18           239016       6117496         0.960322
# 19           238892       6117496         0.960374

# %%
print(os_stat_df.shape)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# (44306, 7)

# %% [markdown]
# - 왜 시간이 15:00:00 으로 바꼈을까..?

# %%
# %%bq query --name stat
# SELECT time, stat_id, value
# FROM `exem-191100.ods_im5.xapm_db_stat`
# WHERE db_id = 6
# ORDER BY time
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query stat
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job___WSfsSpNVx-CYPmhXErIh0WPn-g

# %%
# %%bq query --name stat_eliminatezero
# SELECT stat_id
# FROM(
#   SELECT stat_id, MAX(value) as max_value, MIN(value) as min_value
#   FROM `exem-191100.ods_im5.xapm_db_stat`
#   WHERE db_id = 6
#   GROUP BY stat_id
#   HAVING max_value <> 0  and min_value <> 0
#   ORDER BY stat_id)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query stat_eliminatezero --count 1000
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_0AUhntZVdIyBPzGGSlPPb8z6oYDN

# %%
# %%bq query --name stat
# SELECT time, stat_id, value
# FROM `exem-191100.ods_im5.xapm_db_stat` as t_stat
# WHERE db_id = 6 and EXISTS(
#   SELECT stat_id
#   FROM(
#     SELECT stat_id, MAX(value) as max_value, MIN(value) as min_value
#     FROM `exem-191100.ods_im5.xapm_db_stat`
#     WHERE db_id = 6
#     GROUP BY stat_id
#     HAVING max_value <> 0  and min_value <> 0
#     ORDER BY stat_id) as t_nonzero
#   WHERE t_stat.stat_id = t_nonzero.stat_id
#   ) and stat_id<687
# ORDER BY time, stat_id
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query stat --count 2000000
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_BZCECdz4Xjo8Xzd0avmFEK-wXNPJ

# %% [markdown]
# # stat table 에서 time 당 유의미한 stat_id 의 개수가 34 가 아닌 놈은 하나도 없는것을 검증해보자

# %%
# %%bq query --name stat_test
# SELECT COUNT(time) as total_time
# FROM(
#   SELECT time, COUNT(stat_id) as count
#   FROM `exem-191100.ods_im5.xapm_db_stat` as t_stat
#   WHERE db_id = 6 and EXISTS(
#     SELECT stat_id
#     FROM(
#       SELECT stat_id, MAX(value) as max_value, MIN(value) as min_value
#       FROM `exem-191100.ods_im5.xapm_db_stat`
#       WHERE db_id = 6
#       GROUP BY stat_id
#       HAVING max_value <> 0  and min_value <> 0
#       ORDER BY stat_id) as t_nonzero
#     WHERE t_stat.stat_id = t_nonzero.stat_id
#     ) and stat_id<687
#   GROUP BY time
#   HAVING count <> 34
#   )
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query stat_test
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_GVHu-XDGnTKSTlG2QeXvrCAzTmnY

# %%
# %%bq query --name stat_unix_second
# SELECT UNIX_SECONDS(time) as unix_second
# FROM `exem-191100.ods_im5.xapm_db_stat` as t_stat
# WHERE db_id = 6 and EXISTS(
#   SELECT stat_id
#   FROM(
#     SELECT stat_id, MAX(value) as max_value, MIN(value) as min_value
#     FROM `exem-191100.ods_im5.xapm_db_stat`
#     WHERE db_id = 6
#     GROUP BY stat_id
#     HAVING max_value <> 0  and min_value <> 0
#     ORDER BY stat_id) as t_nonzero
#   WHERE t_stat.stat_id = t_nonzero.stat_id
#   ) and stat_id<687
# GROUP BY time
# ORDER BY time

# %%
stat_unix_second_sql = 'SELECT UNIX_SECONDS(time) as unix_second FROM `exem-191100.ods_im5.xapm_db_stat` as t_stat WHERE db_id = 6 and EXISTS( SELECT stat_id FROM( SELECT stat_id, MAX(value) as max_value, MIN(value) as min_value FROM `exem-191100.ods_im5.xapm_db_stat` WHERE db_id = 6 GROUP BY stat_id HAVING max_value <> 0  and min_value <> 0 ORDER BY stat_id) as t_nonzero WHERE t_stat.stat_id = t_nonzero.stat_id ) and stat_id<687 GROUP BY time ORDER BY time'

stat_unix_second_query = bq.Query(stat_unix_second_sql)

stat_unix_second_df = stat_unix_second_query.execute(output_options = bq.QueryOutput.dataframe()).result()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
print(stat_unix_second_query)
print(stat_unix_second_query.shape)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# BigQuery Query - SELECT UNIX_SECONDS(time) as unix_second FROM `exem-191100.ods_im5.xapm_db_stat` as t_stat WHERE db_id = 6 and EXISTS( SELECT stat_id FROM( SELECT stat_id, MAX(value) as max_value, MIN(value) as min_value FROM `exem-191100.ods_im5.xapm_db_stat` WHERE db_id = 6 GROUP BY stat_id HAVING max_value <> 0  and min_value <> 0 ORDER BY stat_id) as t_nonzero WHERE t_stat.stat_id = t_nonzero.stat_id ) and stat_id<687 GROUP BY time ORDER BY time
# AttributeErrorTraceback (most recent call last)
# <ipython-input-232-b91b1db1ab83> in <module>()
#       1 print(stat_unix_second_query)
# ----> 2 print(stat_unix_second_query.shape)
#
# AttributeError: 'Query' object has no attribute 'shape'

# %%
stat_sql = 'SELECT time, stat_id, value FROM `exem-191100.ods_im5.xapm_db_stat` as t_stat WHERE db_id = 6 and EXISTS( SELECT stat_id FROM( SELECT stat_id, MAX(value) as max_value, MIN(value) as min_value FROM `exem-191100.ods_im5.xapm_db_stat` WHERE db_id = 6 GROUP BY stat_id HAVING max_value <> 0  and min_value <> 0 ORDER BY stat_id) as t_nonzero WHERE t_stat.stat_id = t_nonzero.stat_id ) and stat_id<687 ORDER BY time, stat_id'

stat_query = bq.Query(stat_sql)

stat_df = stat_query.execute(output_options = bq.QueryOutput.dataframe()).result()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
stat_df.head(40)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
#                   time  stat_id     value
# 0  2017-11-03 15:00:00        3        51
# 1  2017-11-03 15:00:00        5        86
# 2  2017-11-03 15:00:00        9    887656
# 3  2017-11-03 15:00:00       10       163
# 4  2017-11-03 15:00:00       14      2221
# 5  2017-11-03 15:00:00       22   1650312
# 6  2017-11-03 15:00:00       26   4662936
# 7  2017-11-03 15:00:00       27       926
# 8  2017-11-03 15:00:00       28  69869335
# 9  2017-11-03 15:00:00       29         0
# 10 2017-11-03 15:00:00       30         0
# 11 2017-11-03 15:00:00       31    170689
# 12 2017-11-03 15:00:00       35        14
# 13 2017-11-03 15:00:00       37    227787
# 14 2017-11-03 15:00:00       38    473547
# 15 2017-11-03 15:00:00       43        59
# 16 2017-11-03 15:00:00       45        59
# 17 2017-11-03 15:00:00       50        38
# 18 2017-11-03 15:00:00       55  11145625
# 19 2017-11-03 15:00:00       61         7
# 20 2017-11-03 15:00:00       63    157952
# 21 2017-11-03 15:00:00       64  11303577
# 22 2017-11-03 15:00:00       88      1960
# 23 2017-11-03 15:00:00       90      1806
# 24 2017-11-03 15:00:00       93  18183782
# 25 2017-11-03 15:00:00      317         0
# 26 2017-11-03 15:00:00      384     14952
# 27 2017-11-03 15:00:00      414    249304
# 28 2017-11-03 15:00:00      573        48
# 29 2017-11-03 15:00:00      617         0
# 30 2017-11-03 15:00:00      679        25
# 31 2017-11-03 15:00:00      680        51
# 32 2017-11-03 15:00:00      681        26
# 33 2017-11-03 15:00:00      683        51
# 34 2017-11-03 15:01:00        3        51
# 35 2017-11-03 15:01:00        5        86
# 36 2017-11-03 15:01:00        9    900186
# 37 2017-11-03 15:01:00       10       163
# 38 2017-11-03 15:01:00       14        23
# 39 2017-11-03 15:01:00       22   1654267

# %%
print(stat_df.shape)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# (1506302, 3)

# %%
# %%bq query --name wait
# SELECT time, event_id, wait_time
# FROM `exem-191100.ods_im5.xapm_db_wait`
# WHERE db_id = 6
# ORDER BY time
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query wait
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_PuotARWZf0K_S7QtbxSw1T6NpXZ8

# %%
df1 = pd.DataFrame([1000, 2000, 3000, 4000],[1, 2, 3, 4])
df2 = pd.DataFrame([1, 2, 3, 4])
df3 = pd.DataFrame(columns = ['A','B'])
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
m1 = df1.as_matrix()
m2 = df2.as_matrix()
m3 = df3.as_matrix()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
timerange_arr = timerange_df.as_matrix()
print(timerange_arr)
print(timerange_arr.shape)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [[  1.50972120e+09]
#  [  1.50972126e+09]
#  [  1.50972132e+09]
#  ...,
#  [  1.51238616e+09]
#  [  1.51238622e+09]
#  [  1.51238628e+09]]
# (44419, 1)

# %%
os_stat_unix_second_arr = os_stat_unix_second_df.as_matrix()
print(os_stat_unix_second_arr)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [[1509721200]
#  [1509721260]
#  [1509721320]
#  ...,
#  [1512386220]
#  [1512386280]
#  [1512386340]]

# %%
print(os_stat_unix_second_arr.shape)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# (44306, 1)

# %%
stat_unix_second_arr = stat_unix_second_df.as_matrix()
print(stat_unix_second_arr)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [[1509721200]
#  [1509721260]
#  [1509721320]
#  ...,
#  [1512386340]
#  [1512386400]
#  [1512386460]]

# %%
print(stat_unix_second_arr.shape)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# (44303, 1)

# %%
stat_arr = stat_df.as_matrix()
os_stat_arr = os_stat_df.as_matrix()
print(stat_arr)
print(os_stat_arr)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [[Timestamp('2017-11-03 15:00:00') 3 51]
#  [Timestamp('2017-11-03 15:00:00') 5 86]
#  [Timestamp('2017-11-03 15:00:00') 9 887656]
#  ...,
#  [Timestamp('2017-12-04 11:21:00') 680 55]
#  [Timestamp('2017-12-04 11:21:00') 681 31]
#  [Timestamp('2017-12-04 11:21:00') 683 55]]
# [[Timestamp('2017-11-03 15:00:00') 5244 6670 ..., 241860 6117496
#   0.9596906969779793]
#  [Timestamp('2017-11-03 15:01:00') 5201 5720 ..., 241844 6117496
#   0.9597863243392395]
#  [Timestamp('2017-11-03 15:02:00') 5168 5460 ..., 241372 6117496
#   0.9598562876052554]
#  ...,
#  [Timestamp('2017-12-04 11:17:00') 5164 5410 ..., 286212 6117496
#   0.9526263686972578]
#  [Timestamp('2017-12-04 11:18:00') 5138 5430 ..., 285584 6117496
#   0.9527183998158724]
#  [Timestamp('2017-12-04 11:19:00') 5257 5690 ..., 285708 6117496
#   0.9528313545280618]]

# %%
print(os_stat_arr.shape)
print(stat_arr.shape)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# (44306, 7)
# (1506302, 3)

# %%
join_arr = [[]]
emp = 0

for i in range(stat_unix_second_arr.shape[0]-2): #44303 -> 44301 (마지막 2개는 stat table에만 있으므로) #687이상의 인덱스를 가진 것들이 남아있었다ㅜㅜ
  stat_time = stat_unix_second_arr[i]
  os_stat_time = os_stat_unix_second_arr[i-emp] #44306 (44301과 5개의 차이 stat table에는 없는데 os table에는 있는 time이 5개..!)
  
  if(i>=42119):
    print(stat_time, os_stat_time)
    
  if(stat_time == os_stat_time):
    temp_arr = np.append([os_stat_time], [os_stat_arr[i-emp]], axis = 1) #44306
    
    for j in range(34): 
      temp_arr = np.append(temp_arr, [[stat_arr[i*34+j][2]]], axis=1) #44303
    
    if(i == 0):
      join_arr = temp_arr
    else:
      join_arr = np.append(join_arr, temp_arr, axis = 0)
  else:
    emp+=1
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# (array([1512255240]), array([1512255180]))
# (array([1512255420]), array([1512255180]))
# (array([1512255480]), array([1512255180]))
# (array([1512255540]), array([1512255180]))
# (array([1512255600]), array([1512255180]))
# (array([1512255660]), array([1512255180]))
# (array([1512255720]), array([1512255180]))
# (array([1512255780]), array([1512255180]))
# (array([1512255840]), array([1512255180]))
# (array([1512255900]), array([1512255180]))
# (array([1512255960]), array([1512255180]))
# (array([1512256020]), array([1512255180]))
# (array([1512256140]), array([1512255180]))
# (array([1512256200]), array([1512255180]))
# (array([1512256320]), array([1512255180]))
# (array([1512256380]), array([1512255180]))
# (array([1512256440]), array([1512255180]))
# (array([1512256500]), array([1512255180]))
# (array([1512256560]), array([1512255180]))
# (array([1512256620]), array([1512255180]))
# (array([1512256680]), array([1512255180]))
# (array([1512256740]), array([1512255180]))
# (array([1512256800]), array([1512255180]))
# (array([1512256860]), array([1512255180]))
# (array([1512256920]), array([1512255180]))
# (array([1512256980]), array([1512255180]))
# (array([1512257040]), array([1512255180]))
# (array([1512257100]), array([1512255180]))
# (array([1512257160]), array([1512255180]))
# (array([1512257220]), array([1512255180]))
# (array([1512257280]), array([1512255180]))
# (array([1512257340]), array([1512255180]))
# (array([1512257400]), array([1512255180]))
# (array([1512257460]), array([1512255180]))
# (array([1512257520]), array([1512255180]))
# (array([1512257580]), array([1512255180]))
# (array([1512257640]), array([1512255180]))
# (array([1512257700]), array([1512255180]))
# (array([1512257760]), array([1512255180]))
# (array([1512257820]), array([1512255180]))
# (array([1512257880]), array([1512255180]))
# (array([1512257940]), array([1512255180]))
# (array([1512258000]), array([1512255180]))
# (array([1512258060]), array([1512255180]))
# (array([1512258120]), array([1512255180]))
# (array([1512258180]), array([1512255180]))
# (array([1512258240]), array([1512255180]))
# (array([1512258300]), array([1512255180]))
# (array([1512258360]), array([1512255180]))
# (array([1512258420]), array([1512255180]))
# (array([1512258480]), array([1512255180]))
# (array([1512258540]), array([1512255180]))
# (array([1512258600]), array([1512255180]))
# (array([1512258660]), array([1512255180]))
# (array([1512258720]), array([1512255180]))
# (array([1512258780]), array([1512255180]))
# (array([1512258840]), array([1512255180]))
# (array([1512258900]), array([1512255180]))
# (array([1512258960]), array([1512255180]))
# (array([1512259020]), array([1512255180]))
# (array([1512259080]), array([1512255180]))
# (array([1512259140]), array([1512255180]))
# (array([1512259200]), array([1512255180]))
# (array([1512259260]), array([1512255180]))
# (array([1512259320]), array([1512255180]))
# (array([1512259380]), array([1512255180]))
# (array([1512259440]), array([1512255180]))
# (array([1512259500]), array([1512255180]))
# (array([1512259560]), array([1512255180]))
# (array([1512259620]), array([1512255180]))
# (array([1512259680]), array([1512255180]))
# (array([1512259740]), array([1512255180]))
# (array([1512259800]), array([1512255180]))
# (array([1512259860]), array([1512255180]))
# (array([1512259920]), array([1512255180]))
# (array([1512259980]), array([1512255180]))
# (array([1512260040]), array([1512255180]))
# (array([1512260100]), array([1512255180]))
# (array([1512260160]), array([1512255180]))
# (array([1512260220]), array([1512255180]))
# (array([1512260280]), array([1512255180]))
# (array([1512260340]), array([1512255180]))
# (array([1512260400]), array([1512255180]))
# (array([1512260460]), array([1512255180]))
# (array([1512260520]), array([1512255180]))
# (array([1512260580]), array([1512255180]))
# (array([1512260640]), array([1512255180]))
# (array([1512260700]), array([1512255180]))
# (array([1512260760]), array([1512255180]))
# (array([1512260820]), array([1512255180]))
# (array([1512260880]), array([1512255180]))
# (array([1512260940]), array([1512255180]))
# (array([1512261000]), array([1512255180]))
# (array([1512261060]), array([1512255180]))
# (array([1512261120]), array([1512255180]))
# (array([1512261180]), array([1512255180]))
# (array([1512261240]), array([1512255180]))
# (array([1512261300]), array([1512255180]))
# (array([1512261360]), array([1512255180]))
# (array([1512261420]), array([1512255180]))
# (array([1512261480]), array([1512255180]))
# (array([1512261540]), array([1512255180]))
# (array([1512261600]), array([1512255180]))
# (array([1512261660]), array([1512255180]))
# (array([1512261720]), array([1512255180]))
# (array([1512261780]), array([1512255180]))
# (array([1512261840]), array([1512255180]))
# (array([1512261900]), array([1512255180]))
# (array([1512261960]), array([1512255180]))
# (array([1512262020]), array([1512255180]))
# (array([1512262080]), array([1512255180]))
# (array([1512262140]), array([1512255180]))
# (array([1512262200]), array([1512255180]))
# (array([1512262260]), array([1512255180]))
# (array([1512262320]), array([1512255180]))
# (array([1512262380]), array([1512255180]))
# (array([1512262440]), array([1512255180]))
# (array([1512262500]), array([1512255180]))
# (array([1512262560]), array([1512255180]))
# (array([1512262620]), array([1512255180]))
# (array([1512262680]), array([1512255180]))
# (array([1512262740]), array([1512255180]))
# (array([1512262800]), array([1512255180]))
# (array([1512262860]), array([1512255180]))
# (array([1512262920]), array([1512255180]))
# (array([1512262980]), array([1512255180]))
# (array([1512263040]), array([1512255180]))
# (array([1512263100]), array([1512255180]))
# (array([1512263160]), array([1512255180]))
# (array([1512263220]), array([1512255180]))
# (array([1512263280]), array([1512255180]))
# (array([1512263340]), array([1512255180]))
# (array([1512263400]), array([1512255180]))
# (array([1512263460]), array([1512255180]))
# (array([1512263520]), array([1512255180]))
# (array([1512263580]), array([1512255180]))
# (array([1512263640]), array([1512255180]))
# (array([1512263700]), array([1512255180]))
# (array([1512263760]), array([1512255180]))
# (array([1512263820]), array([1512255180]))
# (array([1512263880]), array([1512255180]))
# (array([1512263940]), array([1512255180]))
# (array([1512264000]), array([1512255180]))
# (array([1512264060]), array([1512255180]))
# (array([1512264120]), array([1512255180]))
# (array([1512264180]), array([1512255180]))
# (array([1512264240]), array([1512255180]))
# (array([1512264300]), array([1512255180]))
# (array([1512264360]), array([1512255180]))
# (array([1512264420]), array([1512255180]))
# (array([1512264480]), array([1512255180]))
# (array([1512264540]), array([1512255180]))
# (array([1512264600]), array([1512255180]))
# (array([1512264660]), array([1512255180]))
# (array([1512264720]), array([1512255180]))
# (array([1512264780]), array([1512255180]))
# (array([1512264840]), array([1512255180]))
# (array([1512264900]), array([1512255180]))
# (array([1512264960]), array([1512255180]))
# (array([1512265020]), array([1512255180]))
# (array([1512265080]), array([1512255180]))
# (array([1512265140]), array([1512255180]))
# (array([1512265200]), array([1512255180]))
# (array([1512265260]), array([1512255180]))
# (array([1512265320]), array([1512255180]))
# (array([1512265380]), array([1512255180]))
# (array([1512265440]), array([1512255180]))
# (array([1512265500]), array([1512255180]))
# (array([1512265560]), array([1512255180]))
# (array([1512265620]), array([1512255180]))
# (array([1512265680]), array([1512255180]))
# (array([1512265740]), array([1512255180]))
# (array([1512265800]), array([1512255180]))
# (array([1512265860]), array([1512255180]))
# (array([1512265920]), array([1512255180]))
# (array([1512265980]), array([1512255180]))
# (array([1512266040]), array([1512255180]))
# (array([1512266100]), array([1512255180]))
# (array([1512266160]), array([1512255180]))
# (array([1512266220]), array([1512255180]))
# (array([1512266280]), array([1512255180]))
# (array([1512266340]), array([1512255180]))
# (array([1512266400]), array([1512255180]))
# (array([1512266460]), array([1512255180]))
# (array([1512266520]), array([1512255180]))
# (array([1512266580]), array([1512255180]))
# (array([1512266640]), array([1512255180]))
# (array([1512266700]), array([1512255180]))
# (array([1512266760]), array([1512255180]))
# (array([1512266820]), array([1512255180]))
# (array([1512266880]), array([1512255180]))
# (array([1512266940]), array([1512255180]))
# (array([1512267000]), array([1512255180]))
# (array([1512267060]), array([1512255180]))
# (array([1512267120]), array([1512255180]))
# (array([1512267180]), array([1512255180]))
# (array([1512267240]), array([1512255180]))
# (array([1512267300]), array([1512255180]))
# (array([1512267360]), array([1512255180]))
# (array([1512267420]), array([1512255180]))
# (array([1512267480]), array([1512255180]))
# (array([1512267540]), array([1512255180]))
# (array([1512267600]), array([1512255180]))
# (array([1512267660]), array([1512255180]))
# (array([1512267720]), array([1512255180]))
# (array([1512267780]), array([1512255180]))
# (array([1512267840]), array([1512255180]))
# (array([1512267900]), array([1512255180]))
# (array([1512267960]), array([1512255180]))
# (array([1512268020]), array([1512255180]))
# (array([1512268080]), array([1512255180]))
# (array([1512268140]), array([1512255180]))
# (array([1512268200]), array([1512255180]))
# (array([1512268260]), array([1512255180]))
# (array([1512268320]), array([1512255180]))
# (array([1512268380]), array([1512255180]))
# (array([1512268440]), array([1512255180]))
# (array([1512268500]), array([1512255180]))
# (array([1512268560]), array([1512255180]))
# (array([1512268620]), array([1512255180]))
# (array([1512268680]), array([1512255180]))
# (array([1512268740]), array([1512255180]))
# (array([1512268800]), array([1512255180]))
# (array([1512268860]), array([1512255180]))
# (array([1512268920]), array([1512255180]))
# (array([1512268980]), array([1512255180]))
# (array([1512269040]), array([1512255180]))
# (array([1512269100]), array([1512255180]))
# (array([1512269160]), array([1512255180]))
# (array([1512269220]), array([1512255180]))
# (array([1512269280]), array([1512255180]))
# (array([1512269340]), array([1512255180]))
# (array([1512269400]), array([1512255180]))
# (array([1512269460]), array([1512255180]))
# (array([1512269520]), array([1512255180]))
# (array([1512269580]), array([1512255180]))
# (array([1512269640]), array([1512255180]))
# (array([1512269700]), array([1512255180]))
# (array([1512269760]), array([1512255180]))
# (array([1512269820]), array([1512255180]))
# (array([1512269880]), array([1512255180]))
# (array([1512269940]), array([1512255180]))
# (array([1512270000]), array([1512255180]))
# (array([1512270060]), array([1512255180]))
# (array([1512270120]), array([1512255180]))
# (array([1512270180]), array([1512255180]))
# (array([1512270240]), array([1512255180]))
# (array([1512270300]), array([1512255180]))
# (array([1512270360]), array([1512255180]))
# (array([1512270420]), array([1512255180]))
# (array([1512270480]), array([1512255180]))
# (array([1512270540]), array([1512255180]))
# (array([1512270600]), array([1512255180]))
# (array([1512270660]), array([1512255180]))
# (array([1512270720]), array([1512255180]))
# (array([1512270780]), array([1512255180]))
# (array([1512270840]), array([1512255180]))
# (array([1512270900]), array([1512255180]))
# (array([1512270960]), array([1512255180]))
# (array([1512271020]), array([1512255180]))
# (array([1512271080]), array([1512255180]))
# (array([1512271140]), array([1512255180]))
# (array([1512271200]), array([1512255180]))
# (array([1512271260]), array([1512255180]))
# (array([1512271320]), array([1512255180]))
# (array([1512271380]), array([1512255180]))
# (array([1512271440]), array([1512255180]))
# (array([1512271500]), array([1512255180]))
# (array([1512271560]), array([1512255180]))
# (array([1512271620]), array([1512255180]))
# (array([1512271680]), array([1512255180]))
# (array([1512271740]), array([1512255180]))
# (array([1512271800]), array([1512255180]))
# (array([1512271860]), array([1512255180]))
# (array([1512271920]), array([1512255180]))
# (array([1512271980]), array([1512255180]))
# (array([1512272040]), array([1512255180]))
# (array([1512272100]), array([1512255180]))
# (array([1512272160]), array([1512255180]))
# (array([1512272220]), array([1512255180]))
# (array([1512272280]), array([1512255180]))
# (array([1512272340]), array([1512255180]))
# (array([1512272400]), array([1512255180]))
# (array([1512272460]), array([1512255180]))
# (array([1512272520]), array([1512255180]))
# (array([1512272580]), array([1512255180]))
# (array([1512272640]), array([1512255180]))
# (array([1512272700]), array([1512255180]))
# (array([1512272760]), array([1512255180]))
# (array([1512272820]), array([1512255180]))
# (array([1512272880]), array([1512255180]))
# (array([1512272940]), array([1512255180]))
# (array([1512273000]), array([1512255180]))
# (array([1512273060]), array([1512255180]))
# (array([1512273120]), array([1512255180]))
# (array([1512273180]), array([1512255180]))
# (array([1512273240]), array([1512255180]))
# (array([1512273300]), array([1512255180]))
# (array([1512273360]), array([1512255180]))
# (array([1512273420]), array([1512255180]))
# (array([1512273480]), array([1512255180]))
# (array([1512273540]), array([1512255180]))
# (array([1512273600]), array([1512255180]))
# (array([1512273660]), array([1512255180]))
# (array([1512273720]), array([1512255180]))
# (array([1512273780]), array([1512255180]))
# (array([1512273840]), array([1512255180]))
# (array([1512273900]), array([1512255180]))
# (array([1512273960]), array([1512255180]))
# (array([1512274020]), array([1512255180]))
# (array([1512274080]), array([1512255180]))
# (array([1512274140]), array([1512255180]))
# (array([1512274200]), array([1512255180]))
# (array([1512274260]), array([1512255180]))
# (array([1512274320]), array([1512255180]))
# (array([1512274380]), array([1512255180]))
# (array([1512274440]), array([1512255180]))
# (array([1512274500]), array([1512255180]))
# (array([1512274560]), array([1512255180]))
# (array([1512274620]), array([1512255180]))
# (array([1512274680]), array([1512255180]))
# (array([1512274740]), array([1512255180]))
# (array([1512274800]), array([1512255180]))
# (array([1512274860]), array([1512255180]))
# (array([1512274920]), array([1512255180]))
# (array([1512274980]), array([1512255180]))
# (array([1512275040]), array([1512255180]))
# (array([1512275100]), array([1512255180]))
# (array([1512275160]), array([1512255180]))
# (array([1512275220]), array([1512255180]))
# (array([1512275280]), array([1512255180]))
# (array([1512275340]), array([1512255180]))
# (array([1512275400]), array([1512255180]))
# (array([1512275460]), array([1512255180]))
# (array([1512275520]), array([1512255180]))
# (array([1512275580]), array([1512255180]))
# (array([1512275640]), array([1512255180]))
# (array([1512275700]), array([1512255180]))
# (array([1512275760]), array([1512255180]))
# (array([1512275820]), array([1512255180]))
# (array([1512275880]), array([1512255180]))
# (array([1512275940]), array([1512255180]))
# (array([1512276000]), array([1512255180]))
# (array([1512276060]), array([1512255180]))
# (array([1512276120]), array([1512255180]))
# (array([1512276180]), array([1512255180]))
# (array([1512276240]), array([1512255180]))
# (array([1512276300]), array([1512255180]))
# (array([1512276360]), array([1512255180]))
# (array([1512276420]), array([1512255180]))
# (array([1512276480]), array([1512255180]))
# (array([1512276540]), array([1512255180]))
# (array([1512276600]), array([1512255180]))
# (array([1512276660]), array([1512255180]))
# (array([1512276720]), array([1512255180]))
# (array([1512276780]), array([1512255180]))
# (array([1512276840]), array([1512255180]))
# (array([1512276900]), array([1512255180]))
# (array([1512276960]), array([1512255180]))
# (array([1512277020]), array([1512255180]))
# (array([1512277080]), array([1512255180]))
# (array([1512277140]), array([1512255180]))
# (array([1512277200]), array([1512255180]))
# (array([1512277260]), array([1512255180]))
# (array([1512277320]), array([1512255180]))
# (array([1512277380]), array([1512255180]))
# (array([1512277440]), array([1512255180]))
# (array([1512277500]), array([1512255180]))
# (array([1512277560]), array([1512255180]))
# (array([1512277620]), array([1512255180]))
# (array([1512277680]), array([1512255180]))
# (array([1512277740]), array([1512255180]))
# (array([1512277800]), array([1512255180]))
# (array([1512277860]), array([1512255180]))
# (array([1512277920]), array([1512255180]))
# (array([1512277980]), array([1512255180]))
# (array([1512278040]), array([1512255180]))
# (array([1512278100]), array([1512255180]))
# (array([1512278160]), array([1512255180]))
# (array([1512278220]), array([1512255180]))
# (array([1512278280]), array([1512255180]))
# (array([1512278340]), array([1512255180]))
# (array([1512278400]), array([1512255180]))
# (array([1512278460]), array([1512255180]))
# (array([1512278520]), array([1512255180]))
# (array([1512278580]), array([1512255180]))
# (array([1512278640]), array([1512255180]))
# (array([1512278700]), array([1512255180]))
# (array([1512278760]), array([1512255180]))
# (array([1512278820]), array([1512255180]))
# (array([1512278880]), array([1512255180]))
# (array([1512278940]), array([1512255180]))
# (array([1512279000]), array([1512255180]))
# (array([1512279060]), array([1512255180]))
# (array([1512279120]), array([1512255180]))
# (array([1512279180]), array([1512255180]))
# (array([1512279240]), array([1512255180]))
# (array([1512279300]), array([1512255180]))
# (array([1512279360]), array([1512255180]))
# (array([1512279420]), array([1512255180]))
# (array([1512279480]), array([1512255180]))
# (array([1512279540]), array([1512255180]))
# (array([1512279600]), array([1512255180]))
# (array([1512279660]), array([1512255180]))
# (array([1512279720]), array([1512255180]))
# (array([1512279780]), array([1512255180]))
# (array([1512279840]), array([1512255180]))
# (array([1512279900]), array([1512255180]))
# (array([1512279960]), array([1512255180]))
# (array([1512280020]), array([1512255180]))
# (array([1512280080]), array([1512255180]))
# (array([1512280140]), array([1512255180]))
# (array([1512280200]), array([1512255180]))
# (array([1512280260]), array([1512255180]))
# (array([1512280320]), array([1512255180]))
# (array([1512280380]), array([1512255180]))
# (array([1512280440]), array([1512255180]))
# (array([1512280500]), array([1512255180]))
# (array([1512280560]), array([1512255180]))
# (array([1512280620]), array([1512255180]))
# (array([1512280680]), array([1512255180]))
# (array([1512280740]), array([1512255180]))
# (array([1512280800]), array([1512255180]))
# (array([1512280860]), array([1512255180]))
# (array([1512280920]), array([1512255180]))
# (array([1512280980]), array([1512255180]))
# (array([1512281040]), array([1512255180]))
# (array([1512281100]), array([1512255180]))
# (array([1512281160]), array([1512255180]))
# (array([1512281220]), array([1512255180]))
# (array([1512281280]), array([1512255180]))
# (array([1512281340]), array([1512255180]))
# (array([1512281400]), array([1512255180]))
# (array([1512281460]), array([1512255180]))
# (array([1512281520]), array([1512255180]))
# (array([1512281580]), array([1512255180]))
# (array([1512281640]), array([1512255180]))
# (array([1512281700]), array([1512255180]))
# (array([1512281760]), array([1512255180]))
# (array([1512281820]), array([1512255180]))
# (array([1512281880]), array([1512255180]))
# (array([1512281940]), array([1512255180]))
# (array([1512282000]), array([1512255180]))
# (array([1512282060]), array([1512255180]))
# (array([1512282120]), array([1512255180]))
# (array([1512282180]), array([1512255180]))
# (array([1512282240]), array([1512255180]))
# (array([1512282300]), array([1512255180]))
# (array([1512282360]), array([1512255180]))
# (array([1512282420]), array([1512255180]))
# (array([1512282480]), array([1512255180]))
# (array([1512282540]), array([1512255180]))
# (array([1512282600]), array([1512255180]))
# (array([1512282660]), array([1512255180]))
# (array([1512282720]), array([1512255180]))
# (array([1512282780]), array([1512255180]))
# (array([1512282840]), array([1512255180]))
# (array([1512282900]), array([1512255180]))
# (array([1512282960]), array([1512255180]))
# (array([1512283020]), array([1512255180]))
# (array([1512283080]), array([1512255180]))
# (array([1512283140]), array([1512255180]))
# (array([1512283200]), array([1512255180]))
# (array([1512283260]), array([1512255180]))
# (array([1512283320]), array([1512255180]))
# (array([1512283380]), array([1512255180]))
# (array([1512283440]), array([1512255180]))
# (array([1512283500]), array([1512255180]))
# (array([1512283560]), array([1512255180]))
# (array([1512283620]), array([1512255180]))
# (array([1512283680]), array([1512255180]))
# (array([1512283740]), array([1512255180]))
# (array([1512283800]), array([1512255180]))
# (array([1512283860]), array([1512255180]))
# (array([1512283920]), array([1512255180]))
# (array([1512283980]), array([1512255180]))
# (array([1512284040]), array([1512255180]))
# (array([1512284100]), array([1512255180]))
# (array([1512284160]), array([1512255180]))
# (array([1512284220]), array([1512255180]))
# (array([1512284280]), array([1512255180]))
# (array([1512284340]), array([1512255180]))
# (array([1512284400]), array([1512255180]))
# (array([1512284460]), array([1512255180]))
# (array([1512284520]), array([1512255180]))
# (array([1512284580]), array([1512255180]))
# (array([1512284640]), array([1512255180]))
# (array([1512284700]), array([1512255180]))
# (array([1512284760]), array([1512255180]))
# (array([1512284820]), array([1512255180]))
# (array([1512284880]), array([1512255180]))
# (array([1512284940]), array([1512255180]))
# (array([1512285000]), array([1512255180]))
# (array([1512285060]), array([1512255180]))
# (array([1512285120]), array([1512255180]))
# (array([1512285180]), array([1512255180]))
# (array([1512285240]), array([1512255180]))
# (array([1512285300]), array([1512255180]))
# (array([1512285360]), array([1512255180]))
# (array([1512285420]), array([1512255180]))
# (array([1512285480]), array([1512255180]))
# (array([1512285540]), array([1512255180]))
# (array([1512285600]), array([1512255180]))
# (array([1512285660]), array([1512255180]))
# (array([1512285720]), array([1512255180]))
# (array([1512285780]), array([1512255180]))
# (array([1512285840]), array([1512255180]))
# (array([1512285900]), array([1512255180]))
# (array([1512285960]), array([1512255180]))
# (array([1512286020]), array([1512255180]))
# (array([1512286080]), array([1512255180]))
# (array([1512286140]), array([1512255180]))
# (array([1512286200]), array([1512255180]))
# (array([1512286260]), array([1512255180]))
# (array([1512286320]), array([1512255180]))
# (array([1512286380]), array([1512255180]))
# (array([1512286440]), array([1512255180]))
# (array([1512286500]), array([1512255180]))
# (array([1512286560]), array([1512255180]))
# (array([1512286620]), array([1512255180]))
# (array([1512286680]), array([1512255180]))
# (array([1512286740]), array([1512255180]))
# (array([1512286800]), array([1512255180]))
# (array([1512286860]), array([1512255180]))
# (array([1512286920]), array([1512255180]))
# (array([1512286980]), array([1512255180]))
# (array([1512287040]), array([1512255180]))
# (array([1512287100]), array([1512255180]))
# (array([1512287160]), array([1512255180]))
# (array([1512287220]), array([1512255180]))
# (array([1512287280]), array([1512255180]))
# (array([1512287340]), array([1512255180]))
# (array([1512287400]), array([1512255180]))
# (array([1512287460]), array([1512255180]))
# (array([1512287520]), array([1512255180]))
# (array([1512287580]), array([1512255180]))
# (array([1512287640]), array([1512255180]))
# (array([1512287700]), array([1512255180]))
# (array([1512287760]), array([1512255180]))
# (array([1512287820]), array([1512255180]))
# (array([1512287880]), array([1512255180]))
# (array([1512287940]), array([1512255180]))
# (array([1512288000]), array([1512255180]))
# (array([1512288060]), array([1512255180]))
# (array([1512288120]), array([1512255180]))
# (array([1512288180]), array([1512255180]))
# (array([1512288240]), array([1512255180]))
# (array([1512288300]), array([1512255180]))
# (array([1512288360]), array([1512255180]))
# (array([1512288420]), array([1512255180]))
# (array([1512288480]), array([1512255180]))
# (array([1512288540]), array([1512255180]))
# (array([1512288600]), array([1512255180]))
# (array([1512288660]), array([1512255180]))
# (array([1512288720]), array([1512255180]))
# (array([1512288780]), array([1512255180]))
# (array([1512288840]), array([1512255180]))
# (array([1512288900]), array([1512255180]))
# (array([1512288960]), array([1512255180]))
# (array([1512289020]), array([1512255180]))
# (array([1512289080]), array([1512255180]))
# (array([1512289140]), array([1512255180]))
# (array([1512289200]), array([1512255180]))
# (array([1512289260]), array([1512255180]))
# (array([1512289320]), array([1512255180]))
# (array([1512289380]), array([1512255180]))
# (array([1512289440]), array([1512255180]))
# (array([1512289500]), array([1512255180]))
# (array([1512289560]), array([1512255180]))
# (array([1512289620]), array([1512255180]))
# (array([1512289680]), array([1512255180]))
# (array([1512289740]), array([1512255180]))
# (array([1512289800]), array([1512255180]))
# (array([1512289860]), array([1512255180]))
# (array([1512289920]), array([1512255180]))
# (array([1512289980]), array([1512255180]))
# (array([1512290040]), array([1512255180]))
# (array([1512290100]), array([1512255180]))
# (array([1512290160]), array([1512255180]))
# (array([1512290220]), array([1512255180]))
# (array([1512290280]), array([1512255180]))
# (array([1512290340]), array([1512255180]))
# (array([1512290400]), array([1512255180]))
# (array([1512290460]), array([1512255180]))
# (array([1512290520]), array([1512255180]))
# (array([1512290580]), array([1512255180]))
# (array([1512290640]), array([1512255180]))
# (array([1512290700]), array([1512255180]))
# (array([1512290760]), array([1512255180]))
# (array([1512290820]), array([1512255180]))
# (array([1512290880]), array([1512255180]))
# (array([1512290940]), array([1512255180]))
# (array([1512291000]), array([1512255180]))
# (array([1512291060]), array([1512255180]))
# (array([1512291120]), array([1512255180]))
# (array([1512291180]), array([1512255180]))
# (array([1512291240]), array([1512255180]))
# (array([1512291300]), array([1512255180]))
# (array([1512291360]), array([1512255180]))
# (array([1512291420]), array([1512255180]))
# (array([1512291480]), array([1512255180]))
# (array([1512291540]), array([1512255180]))
# (array([1512291600]), array([1512255180]))
# (array([1512291660]), array([1512255180]))
# (array([1512291720]), array([1512255180]))
# (array([1512291780]), array([1512255180]))
# (array([1512291840]), array([1512255180]))
# (array([1512291900]), array([1512255180]))
# (array([1512291960]), array([1512255180]))
# (array([1512292020]), array([1512255180]))
# (array([1512292080]), array([1512255180]))
# (array([1512292140]), array([1512255180]))
# (array([1512292200]), array([1512255180]))
# (array([1512292260]), array([1512255180]))
# (array([1512292320]), array([1512255180]))
# (array([1512292380]), array([1512255180]))
# (array([1512292440]), array([1512255180]))
# (array([1512292500]), array([1512255180]))
# (array([1512292560]), array([1512255180]))
# (array([1512292620]), array([1512255180]))
# (array([1512292680]), array([1512255180]))
# (array([1512292740]), array([1512255180]))
# (array([1512292800]), array([1512255180]))
# (array([1512292860]), array([1512255180]))
# (array([1512292920]), array([1512255180]))
# (array([1512292980]), array([1512255180]))
# (array([1512293040]), array([1512255180]))
# (array([1512293100]), array([1512255180]))
# (array([1512293160]), array([1512255180]))
# (array([1512293220]), array([1512255180]))
# (array([1512293280]), array([1512255180]))
# (array([1512293340]), array([1512255180]))
# (array([1512293400]), array([1512255180]))
# (array([1512293460]), array([1512255180]))
# (array([1512293520]), array([1512255180]))
# (array([1512293580]), array([1512255180]))
# (array([1512293640]), array([1512255180]))
# (array([1512293700]), array([1512255180]))
# (array([1512293760]), array([1512255180]))
# (array([1512293820]), array([1512255180]))
# (array([1512293880]), array([1512255180]))
# (array([1512293940]), array([1512255180]))
# (array([1512294000]), array([1512255180]))
# (array([1512294060]), array([1512255180]))
# (array([1512294120]), array([1512255180]))
# (array([1512294180]), array([1512255180]))
# (array([1512294240]), array([1512255180]))
# (array([1512294300]), array([1512255180]))
# (array([1512294360]), array([1512255180]))
# (array([1512294420]), array([1512255180]))
# (array([1512294480]), array([1512255180]))
# (array([1512294540]), array([1512255180]))
# (array([1512294600]), array([1512255180]))
# (array([1512294660]), array([1512255180]))
# (array([1512294720]), array([1512255180]))
# (array([1512294780]), array([1512255180]))
# (array([1512294840]), array([1512255180]))
# (array([1512294900]), array([1512255180]))
# (array([1512294960]), array([1512255180]))
# (array([1512295020]), array([1512255180]))
# (array([1512295080]), array([1512255180]))
# (array([1512295140]), array([1512255180]))
# (array([1512295200]), array([1512255180]))
# (array([1512295260]), array([1512255180]))
# (array([1512295320]), array([1512255180]))
# (array([1512295380]), array([1512255180]))
# (array([1512295440]), array([1512255180]))
# (array([1512295500]), array([1512255180]))
# (array([1512295560]), array([1512255180]))
# (array([1512295620]), array([1512255180]))
# (array([1512295680]), array([1512255180]))
# (array([1512295740]), array([1512255180]))
# (array([1512295800]), array([1512255180]))
# (array([1512295860]), array([1512255180]))
# (array([1512295920]), array([1512255180]))
# (array([1512295980]), array([1512255180]))
# (array([1512296040]), array([1512255180]))
# (array([1512296100]), array([1512255180]))
# (array([1512296160]), array([1512255180]))
# (array([1512296220]), array([1512255180]))
# (array([1512296280]), array([1512255180]))
# (array([1512296340]), array([1512255180]))
# (array([1512296400]), array([1512255180]))
# (array([1512296460]), array([1512255180]))
# (array([1512296520]), array([1512255180]))
# (array([1512296580]), array([1512255180]))
# (array([1512296640]), array([1512255180]))
# (array([1512296700]), array([1512255180]))
# (array([1512296760]), array([1512255180]))
# (array([1512296820]), array([1512255180]))
# (array([1512296880]), array([1512255180]))
# (array([1512296940]), array([1512255180]))
# (array([1512297000]), array([1512255180]))
# (array([1512297060]), array([1512255180]))
# (array([1512297120]), array([1512255180]))
# (array([1512297180]), array([1512255180]))
# (array([1512297240]), array([1512255180]))
# (array([1512297300]), array([1512255180]))
# (array([1512297360]), array([1512255180]))
# (array([1512297420]), array([1512255180]))
# (array([1512297480]), array([1512255180]))
# (array([1512297540]), array([1512255180]))
# (array([1512297600]), array([1512255180]))
# (array([1512297660]), array([1512255180]))
# (array([1512297720]), array([1512255180]))
# (array([1512297780]), array([1512255180]))
# (array([1512297840]), array([1512255180]))
# (array([1512297900]), array([1512255180]))
# (array([1512297960]), array([1512255180]))
# (array([1512298020]), array([1512255180]))
# (array([1512298080]), array([1512255180]))
# (array([1512298140]), array([1512255180]))
# (array([1512298200]), array([1512255180]))
# (array([1512298260]), array([1512255180]))
# (array([1512298320]), array([1512255180]))
# (array([1512298380]), array([1512255180]))
# (array([1512298440]), array([1512255180]))
# (array([1512298500]), array([1512255180]))
# (array([1512298560]), array([1512255180]))
# (array([1512298620]), array([1512255180]))
# (array([1512298680]), array([1512255180]))
# (array([1512298740]), array([1512255180]))
# (array([1512298800]), array([1512255180]))
# (array([1512298860]), array([1512255180]))
# (array([1512298920]), array([1512255180]))
# (array([1512298980]), array([1512255180]))
# (array([1512299040]), array([1512255180]))
# (array([1512299100]), array([1512255180]))
# (array([1512299160]), array([1512255180]))
# (array([1512299220]), array([1512255180]))
# (array([1512299280]), array([1512255180]))
# (array([1512299340]), array([1512255180]))
# (array([1512299400]), array([1512255180]))
# (array([1512299460]), array([1512255180]))
# (array([1512299520]), array([1512255180]))
# (array([1512299580]), array([1512255180]))
# (array([1512299640]), array([1512255180]))
# (array([1512299700]), array([1512255180]))
# (array([1512299760]), array([1512255180]))
# (array([1512299820]), array([1512255180]))
# (array([1512299880]), array([1512255180]))
# (array([1512299940]), array([1512255180]))
# (array([1512300000]), array([1512255180]))
# (array([1512300060]), array([1512255180]))
# (array([1512300120]), array([1512255180]))
# (array([1512300180]), array([1512255180]))
# (array([1512300240]), array([1512255180]))
# (array([1512300300]), array([1512255180]))
# (array([1512300360]), array([1512255180]))
# (array([1512300420]), array([1512255180]))
# (array([1512300480]), array([1512255180]))
# (array([1512300540]), array([1512255180]))
# (array([1512300600]), array([1512255180]))
# (array([1512300660]), array([1512255180]))
# (array([1512300720]), array([1512255180]))
# (array([1512300780]), array([1512255180]))
# (array([1512300840]), array([1512255180]))
# (array([1512300900]), array([1512255180]))
# (array([1512300960]), array([1512255180]))
# (array([1512301020]), array([1512255180]))
# (array([1512301080]), array([1512255180]))
# (array([1512301140]), array([1512255180]))
# (array([1512301200]), array([1512255180]))
# (array([1512301260]), array([1512255180]))
# (array([1512301320]), array([1512255180]))
# (array([1512301380]), array([1512255180]))
# (array([1512301440]), array([1512255180]))
# (array([1512301500]), array([1512255180]))
# (array([1512301560]), array([1512255180]))
# (array([1512301620]), array([1512255180]))
# (array([1512301680]), array([1512255180]))
# (array([1512301740]), array([1512255180]))
# (array([1512301800]), array([1512255180]))
# (array([1512301860]), array([1512255180]))
# (array([1512301920]), array([1512255180]))
# (array([1512301980]), array([1512255180]))
# (array([1512302040]), array([1512255180]))
# (array([1512302100]), array([1512255180]))
# (array([1512302160]), array([1512255180]))
# (array([1512302220]), array([1512255180]))
# (array([1512302280]), array([1512255180]))
# (array([1512302340]), array([1512255180]))
# (array([1512302400]), array([1512255180]))
# (array([1512302460]), array([1512255180]))
# (array([1512302520]), array([1512255180]))
# (array([1512302580]), array([1512255180]))
# (array([1512302640]), array([1512255180]))
# (array([1512302700]), array([1512255180]))
# (array([1512302760]), array([1512255180]))
# (array([1512302820]), array([1512255180]))
# (array([1512302880]), array([1512255180]))
# (array([1512302940]), array([1512255180]))
# (array([1512303000]), array([1512255180]))
# (array([1512303060]), array([1512255180]))
# (array([1512303120]), array([1512255180]))
# (array([1512303180]), array([1512255180]))
# (array([1512303240]), array([1512255180]))
# (array([1512303300]), array([1512255180]))
# (array([1512303360]), array([1512255180]))
# (array([1512303420]), array([1512255180]))
# (array([1512303480]), array([1512255180]))
# (array([1512303540]), array([1512255180]))
# (array([1512303600]), array([1512255180]))
# (array([1512303660]), array([1512255180]))
# (array([1512303720]), array([1512255180]))
# (array([1512303780]), array([1512255180]))
# (array([1512303840]), array([1512255180]))
# (array([1512303900]), array([1512255180]))
# (array([1512303960]), array([1512255180]))
# (array([1512304020]), array([1512255180]))
# (array([1512304080]), array([1512255180]))
# (array([1512304140]), array([1512255180]))
# (array([1512304200]), array([1512255180]))
# (array([1512304260]), array([1512255180]))
# (array([1512304320]), array([1512255180]))
# (array([1512304380]), array([1512255180]))
# (array([1512304440]), array([1512255180]))
# (array([1512304500]), array([1512255180]))
# (array([1512304560]), array([1512255180]))
# (array([1512304620]), array([1512255180]))
# (array([1512304680]), array([1512255180]))
# (array([1512304740]), array([1512255180]))
# (array([1512304800]), array([1512255180]))
# (array([1512304860]), array([1512255180]))
# (array([1512304920]), array([1512255180]))
# (array([1512304980]), array([1512255180]))
# (array([1512305040]), array([1512255180]))
# (array([1512305100]), array([1512255180]))
# (array([1512305160]), array([1512255180]))
# (array([1512305220]), array([1512255180]))
# (array([1512305280]), array([1512255180]))
# (array([1512305340]), array([1512255180]))
# (array([1512305400]), array([1512255180]))
# (array([1512305460]), array([1512255180]))
# (array([1512305520]), array([1512255180]))
# (array([1512305580]), array([1512255180]))
# (array([1512305640]), array([1512255180]))
# (array([1512305700]), array([1512255180]))
# (array([1512305760]), array([1512255180]))
# (array([1512305820]), array([1512255180]))
# (array([1512305880]), array([1512255180]))
# (array([1512305940]), array([1512255180]))
# (array([1512306000]), array([1512255180]))
# (array([1512306060]), array([1512255180]))
# (array([1512306120]), array([1512255180]))
# (array([1512306180]), array([1512255180]))
# (array([1512306240]), array([1512255180]))
# (array([1512306300]), array([1512255180]))
# (array([1512306360]), array([1512255180]))
# (array([1512306420]), array([1512255180]))
# (array([1512306480]), array([1512255180]))
# (array([1512306540]), array([1512255180]))
# (array([1512306600]), array([1512255180]))
# (array([1512306660]), array([1512255180]))
# (array([1512306720]), array([1512255180]))
# (array([1512306780]), array([1512255180]))
# (array([1512306840]), array([1512255180]))
# (array([1512306900]), array([1512255180]))
# (array([1512306960]), array([1512255180]))
# (array([1512307020]), array([1512255180]))
# (array([1512307080]), array([1512255180]))
# (array([1512307140]), array([1512255180]))
# (array([1512307200]), array([1512255180]))
# (array([1512307260]), array([1512255180]))
# (array([1512307320]), array([1512255180]))
# (array([1512307380]), array([1512255180]))
# (array([1512307440]), array([1512255180]))
# (array([1512307500]), array([1512255180]))
# (array([1512307560]), array([1512255180]))
# (array([1512307620]), array([1512255180]))
# (array([1512307680]), array([1512255180]))
# (array([1512307740]), array([1512255180]))
# (array([1512307800]), array([1512255180]))
# (array([1512307860]), array([1512255180]))
# (array([1512307920]), array([1512255180]))
# (array([1512307980]), array([1512255180]))
# (array([1512308040]), array([1512255180]))
# (array([1512308100]), array([1512255180]))
# (array([1512308160]), array([1512255180]))
# (array([1512308220]), array([1512255180]))
# (array([1512308280]), array([1512255180]))
# (array([1512308340]), array([1512255180]))
# (array([1512308400]), array([1512255180]))
# (array([1512308460]), array([1512255180]))
# (array([1512308520]), array([1512255180]))
# (array([1512308580]), array([1512255180]))
# (array([1512308640]), array([1512255180]))
# (array([1512308700]), array([1512255180]))
# (array([1512308760]), array([1512255180]))
# (array([1512308820]), array([1512255180]))
# (array([1512308880]), array([1512255180]))
# (array([1512308940]), array([1512255180]))
# (array([1512309000]), array([1512255180]))
# (array([1512309060]), array([1512255180]))
# (array([1512309120]), array([1512255180]))
# (array([1512309180]), array([1512255180]))
# (array([1512309240]), array([1512255180]))
# (array([1512309300]), array([1512255180]))
# (array([1512309360]), array([1512255180]))
# (array([1512309420]), array([1512255180]))
# (array([1512309480]), array([1512255180]))
# (array([1512309540]), array([1512255180]))
# (array([1512309600]), array([1512255180]))
# (array([1512309660]), array([1512255180]))
# (array([1512309720]), array([1512255180]))
# (array([1512309780]), array([1512255180]))
# (array([1512309840]), array([1512255180]))
# (array([1512309900]), array([1512255180]))
# (array([1512309960]), array([1512255180]))
# (array([1512310020]), array([1512255180]))
# (array([1512310080]), array([1512255180]))
# (array([1512310140]), array([1512255180]))
# (array([1512310200]), array([1512255180]))
# (array([1512310260]), array([1512255180]))
# (array([1512310320]), array([1512255180]))
# (array([1512310380]), array([1512255180]))
# (array([1512310440]), array([1512255180]))
# (array([1512310500]), array([1512255180]))
# (array([1512310560]), array([1512255180]))
# (array([1512310620]), array([1512255180]))
# (array([1512310680]), array([1512255180]))
# (array([1512310740]), array([1512255180]))
# (array([1512310800]), array([1512255180]))
# (array([1512310860]), array([1512255180]))
# (array([1512310920]), array([1512255180]))
# (array([1512310980]), array([1512255180]))
# (array([1512311040]), array([1512255180]))
# (array([1512311100]), array([1512255180]))
# (array([1512311160]), array([1512255180]))
# (array([1512311220]), array([1512255180]))
# (array([1512311280]), array([1512255180]))
# (array([1512311340]), array([1512255180]))
# (array([1512311400]), array([1512255180]))
# (array([1512311460]), array([1512255180]))
# (array([1512311520]), array([1512255180]))
# (array([1512311580]), array([1512255180]))
# (array([1512311640]), array([1512255180]))
# (array([1512311700]), array([1512255180]))
# (array([1512311760]), array([1512255180]))
# (array([1512311820]), array([1512255180]))
# (array([1512311880]), array([1512255180]))
# (array([1512311940]), array([1512255180]))
# (array([1512312000]), array([1512255180]))
# (array([1512312060]), array([1512255180]))
# (array([1512312120]), array([1512255180]))
# (array([1512312180]), array([1512255180]))
# (array([1512312240]), array([1512255180]))
# (array([1512312300]), array([1512255180]))
# (array([1512312360]), array([1512255180]))
# (array([1512312420]), array([1512255180]))
# (array([1512312480]), array([1512255180]))
# (array([1512312540]), array([1512255180]))
# (array([1512312600]), array([1512255180]))
# (array([1512312660]), array([1512255180]))
# (array([1512312720]), array([1512255180]))
# (array([1512312780]), array([1512255180]))
# (array([1512312840]), array([1512255180]))
# (array([1512312900]), array([1512255180]))
# (array([1512312960]), array([1512255180]))
# (array([1512313020]), array([1512255180]))
# (array([1512313080]), array([1512255180]))
# (array([1512313140]), array([1512255180]))
# (array([1512313200]), array([1512255180]))
# (array([1512313260]), array([1512255180]))
# (array([1512313320]), array([1512255180]))
# (array([1512313380]), array([1512255180]))
# (array([1512313440]), array([1512255180]))
# (array([1512313500]), array([1512255180]))
# (array([1512313560]), array([1512255180]))
# (array([1512313620]), array([1512255180]))
# (array([1512313680]), array([1512255180]))
# (array([1512313740]), array([1512255180]))
# (array([1512313800]), array([1512255180]))
# (array([1512313860]), array([1512255180]))
# (array([1512313920]), array([1512255180]))
# (array([1512313980]), array([1512255180]))
# (array([1512314040]), array([1512255180]))
# (array([1512314100]), array([1512255180]))
# (array([1512314160]), array([1512255180]))
# (array([1512314220]), array([1512255180]))
# (array([1512314280]), array([1512255180]))
# (array([1512314340]), array([1512255180]))
# (array([1512314400]), array([1512255180]))
# (array([1512314460]), array([1512255180]))
# (array([1512314520]), array([1512255180]))
# (array([1512314580]), array([1512255180]))
# (array([1512314640]), array([1512255180]))
# (array([1512314700]), array([1512255180]))
# (array([1512314760]), array([1512255180]))
# (array([1512314820]), array([1512255180]))
# (array([1512314880]), array([1512255180]))
# (array([1512314940]), array([1512255180]))
# (array([1512315000]), array([1512255180]))
# (array([1512315060]), array([1512255180]))
# (array([1512315120]), array([1512255180]))
# (array([1512315180]), array([1512255180]))
# (array([1512315240]), array([1512255180]))
# (array([1512315300]), array([1512255180]))
# (array([1512315360]), array([1512255180]))
# (array([1512315420]), array([1512255180]))
# (array([1512315480]), array([1512255180]))
# (array([1512315540]), array([1512255180]))
# (array([1512315600]), array([1512255180]))
# (array([1512315660]), array([1512255180]))
# (array([1512315720]), array([1512255180]))
# (array([1512315780]), array([1512255180]))
# (array([1512315840]), array([1512255180]))
# (array([1512315900]), array([1512255180]))
# (array([1512315960]), array([1512255180]))
# (array([1512316020]), array([1512255180]))
# (array([1512316080]), array([1512255180]))
# (array([1512316140]), array([1512255180]))
# (array([1512316200]), array([1512255180]))
# (array([1512316260]), array([1512255180]))
# (array([1512316320]), array([1512255180]))
# (array([1512316380]), array([1512255180]))
# (array([1512316440]), array([1512255180]))
# (array([1512316500]), array([1512255180]))
# (array([1512316560]), array([1512255180]))
# (array([1512316620]), array([1512255180]))
# (array([1512316680]), array([1512255180]))
# (array([1512316740]), array([1512255180]))
# (array([1512316800]), array([1512255180]))
# (array([1512316860]), array([1512255180]))
# (array([1512316920]), array([1512255180]))
# (array([1512316980]), array([1512255180]))
# (array([1512317040]), array([1512255180]))
# (array([1512317100]), array([1512255180]))
# (array([1512317160]), array([1512255180]))
# (array([1512317220]), array([1512255180]))
# (array([1512317280]), array([1512255180]))
# (array([1512317340]), array([1512255180]))
# (array([1512317400]), array([1512255180]))
# (array([1512317460]), array([1512255180]))
# (array([1512317520]), array([1512255180]))
# (array([1512317580]), array([1512255180]))
# (array([1512317640]), array([1512255180]))
# (array([1512317700]), array([1512255180]))
# (array([1512317760]), array([1512255180]))
# (array([1512317820]), array([1512255180]))
# (array([1512317880]), array([1512255180]))
# (array([1512317940]), array([1512255180]))
# (array([1512318000]), array([1512255180]))
# (array([1512318060]), array([1512255180]))
# (array([1512318120]), array([1512255180]))
# (array([1512318180]), array([1512255180]))
# (array([1512318240]), array([1512255180]))
# (array([1512318300]), array([1512255180]))
# (array([1512318360]), array([1512255180]))
# (array([1512318420]), array([1512255180]))
# (array([1512318480]), array([1512255180]))
# (array([1512318540]), array([1512255180]))
# (array([1512318600]), array([1512255180]))
# (array([1512318660]), array([1512255180]))
# (array([1512318720]), array([1512255180]))
# (array([1512318780]), array([1512255180]))
# (array([1512318840]), array([1512255180]))
# (array([1512318900]), array([1512255180]))
# (array([1512318960]), array([1512255180]))
# (array([1512319020]), array([1512255180]))
# (array([1512319080]), array([1512255180]))
# (array([1512319140]), array([1512255180]))
# (array([1512319200]), array([1512255180]))
# (array([1512319260]), array([1512255180]))
# (array([1512319320]), array([1512255180]))
# (array([1512319380]), array([1512255180]))
# (array([1512319440]), array([1512255180]))
# (array([1512319500]), array([1512255180]))
# (array([1512319560]), array([1512255180]))
# (array([1512319620]), array([1512255180]))
# (array([1512319680]), array([1512255180]))
# (array([1512319740]), array([1512255180]))
# (array([1512319800]), array([1512255180]))
# (array([1512319860]), array([1512255180]))
# (array([1512319920]), array([1512255180]))
# (array([1512319980]), array([1512255180]))
# (array([1512320040]), array([1512255180]))
# (array([1512320100]), array([1512255180]))
# (array([1512320160]), array([1512255180]))
# (array([1512320220]), array([1512255180]))
# (array([1512320280]), array([1512255180]))
# (array([1512320340]), array([1512255180]))
# (array([1512320400]), array([1512255180]))
# (array([1512320460]), array([1512255180]))
# (array([1512320520]), array([1512255180]))
# (array([1512320580]), array([1512255180]))
# (array([1512320640]), array([1512255180]))
# (array([1512320700]), array([1512255180]))
# (array([1512320760]), array([1512255180]))
# (array([1512320820]), array([1512255180]))
# (array([1512320880]), array([1512255180]))
# (array([1512320940]), array([1512255180]))
# (array([1512321000]), array([1512255180]))
# (array([1512321060]), array([1512255180]))
# (array([1512321120]), array([1512255180]))
# (array([1512321180]), array([1512255180]))
# (array([1512321240]), array([1512255180]))
# (array([1512321300]), array([1512255180]))
# (array([1512321360]), array([1512255180]))
# (array([1512321420]), array([1512255180]))
# (array([1512321480]), array([1512255180]))
# (array([1512321540]), array([1512255180]))
# (array([1512321600]), array([1512255180]))
# (array([1512321660]), array([1512255180]))
# (array([1512321720]), array([1512255180]))
# (array([1512321780]), array([1512255180]))
# (array([1512321840]), array([1512255180]))
# (array([1512321900]), array([1512255180]))
# (array([1512321960]), array([1512255180]))
# (array([1512322020]), array([1512255180]))
# ...
# (array([1512364080]), array([1512255180]))
# (array([1512364140]), array([1512255180]))
# (array([1512364200]), array([1512255180]))
# (array([1512364260]), array([1512255180]))
# (array([1512364320]), array([1512255180]))
# (array([1512364380]), array([1512255180]))
# (array([1512364440]), array([1512255180]))
# (array([1512364500]), array([1512255180]))
# (array([1512364560]), array([1512255180]))
# (array([1512364620]), array([1512255180]))
# (array([1512364680]), array([1512255180]))
# (array([1512364740]), array([1512255180]))
# (array([1512364800]), array([1512255180]))
# (array([1512364860]), array([1512255180]))
# (array([1512364920]), array([1512255180]))
# (array([1512364980]), array([1512255180]))
# (array([1512365040]), array([1512255180]))
# (array([1512365100]), array([1512255180]))
# (array([1512365160]), array([1512255180]))
# (array([1512365220]), array([1512255180]))
# (array([1512365280]), array([1512255180]))
# (array([1512365340]), array([1512255180]))
# (array([1512365400]), array([1512255180]))
# (array([1512365460]), array([1512255180]))
# (array([1512365520]), array([1512255180]))
# (array([1512365580]), array([1512255180]))
# (array([1512365640]), array([1512255180]))
# (array([1512365700]), array([1512255180]))
# (array([1512365760]), array([1512255180]))
# (array([1512365820]), array([1512255180]))
# (array([1512365880]), array([1512255180]))
# (array([1512365940]), array([1512255180]))
# (array([1512366000]), array([1512255180]))
# (array([1512366060]), array([1512255180]))
# (array([1512366120]), array([1512255180]))
# (array([1512366180]), array([1512255180]))
# (array([1512366240]), array([1512255180]))
# (array([1512366300]), array([1512255180]))
# (array([1512366360]), array([1512255180]))
# (array([1512366420]), array([1512255180]))
# (array([1512366480]), array([1512255180]))
# (array([1512366540]), array([1512255180]))
# (array([1512366600]), array([1512255180]))
# (array([1512366660]), array([1512255180]))
# (array([1512366720]), array([1512255180]))
# (array([1512366780]), array([1512255180]))
# (array([1512366840]), array([1512255180]))
# (array([1512366900]), array([1512255180]))
# (array([1512366960]), array([1512255180]))
# (array([1512367020]), array([1512255180]))
# (array([1512367080]), array([1512255180]))
# (array([1512367140]), array([1512255180]))
# (array([1512367200]), array([1512255180]))
# (array([1512367260]), array([1512255180]))
# (array([1512367320]), array([1512255180]))
# (array([1512367380]), array([1512255180]))
# (array([1512367440]), array([1512255180]))
# (array([1512367500]), array([1512255180]))
# (array([1512367560]), array([1512255180]))
# (array([1512367620]), array([1512255180]))
# (array([1512367680]), array([1512255180]))
# (array([1512367740]), array([1512255180]))
# (array([1512367800]), array([1512255180]))
# (array([1512367860]), array([1512255180]))
# (array([1512367920]), array([1512255180]))
# (array([1512367980]), array([1512255180]))
# (array([1512368040]), array([1512255180]))
# (array([1512368100]), array([1512255180]))
# (array([1512368160]), array([1512255180]))
# (array([1512368220]), array([1512255180]))
# (array([1512368280]), array([1512255180]))
# (array([1512368340]), array([1512255180]))
# (array([1512368400]), array([1512255180]))
# (array([1512368460]), array([1512255180]))
# (array([1512368520]), array([1512255180]))
# (array([1512368580]), array([1512255180]))
# (array([1512368640]), array([1512255180]))
# (array([1512368700]), array([1512255180]))
# (array([1512368760]), array([1512255180]))
# (array([1512368820]), array([1512255180]))
# (array([1512368880]), array([1512255180]))
# (array([1512368940]), array([1512255180]))
# (array([1512369000]), array([1512255180]))
# (array([1512369060]), array([1512255180]))
# (array([1512369120]), array([1512255180]))
# (array([1512369180]), array([1512255180]))
# (array([1512369240]), array([1512255180]))
# (array([1512369300]), array([1512255180]))
# (array([1512369360]), array([1512255180]))
# (array([1512369420]), array([1512255180]))
# (array([1512369480]), array([1512255180]))
# (array([1512369540]), array([1512255180]))
# (array([1512369600]), array([1512255180]))
# (array([1512369660]), array([1512255180]))
# (array([1512369720]), array([1512255180]))
# (array([1512369780]), array([1512255180]))
# (array([1512369840]), array([1512255180]))
# (array([1512369900]), array([1512255180]))
# (array([1512369960]), array([1512255180]))
# (array([1512370020]), array([1512255180]))
# (array([1512370080]), array([1512255180]))
# (array([1512370140]), array([1512255180]))
# (array([1512370200]), array([1512255180]))
# (array([1512370260]), array([1512255180]))
# (array([1512370320]), array([1512255180]))
# (array([1512370380]), array([1512255180]))
# (array([1512370440]), array([1512255180]))
# (array([1512370500]), array([1512255180]))
# (array([1512370560]), array([1512255180]))
# (array([1512370620]), array([1512255180]))
# (array([1512370680]), array([1512255180]))
# (array([1512370740]), array([1512255180]))
# (array([1512370800]), array([1512255180]))
# (array([1512370860]), array([1512255180]))
# (array([1512370920]), array([1512255180]))
# (array([1512370980]), array([1512255180]))
# (array([1512371040]), array([1512255180]))
# (array([1512371100]), array([1512255180]))
# (array([1512371160]), array([1512255180]))
# (array([1512371220]), array([1512255180]))
# (array([1512371280]), array([1512255180]))
# (array([1512371340]), array([1512255180]))
# (array([1512371400]), array([1512255180]))
# (array([1512371460]), array([1512255180]))
# (array([1512371520]), array([1512255180]))
# (array([1512371580]), array([1512255180]))
# (array([1512371640]), array([1512255180]))
# (array([1512371700]), array([1512255180]))
# (array([1512371760]), array([1512255180]))
# (array([1512371820]), array([1512255180]))
# (array([1512371880]), array([1512255180]))
# (array([1512371940]), array([1512255180]))
# (array([1512372000]), array([1512255180]))
# (array([1512372060]), array([1512255180]))
# (array([1512372120]), array([1512255180]))
# (array([1512372180]), array([1512255180]))
# (array([1512372240]), array([1512255180]))
# (array([1512372300]), array([1512255180]))
# (array([1512372360]), array([1512255180]))
# (array([1512372420]), array([1512255180]))
# (array([1512372480]), array([1512255180]))
# (array([1512372540]), array([1512255180]))
# (array([1512372600]), array([1512255180]))
# (array([1512372660]), array([1512255180]))
# (array([1512372720]), array([1512255180]))
# (array([1512372780]), array([1512255180]))
# (array([1512372840]), array([1512255180]))
# (array([1512372900]), array([1512255180]))
# (array([1512372960]), array([1512255180]))
# (array([1512373020]), array([1512255180]))
# (array([1512373080]), array([1512255180]))
# (array([1512373140]), array([1512255180]))
# (array([1512373200]), array([1512255180]))
# (array([1512373260]), array([1512255180]))
# (array([1512373320]), array([1512255180]))
# (array([1512373380]), array([1512255180]))
# (array([1512373440]), array([1512255180]))
# (array([1512373500]), array([1512255180]))
# (array([1512373560]), array([1512255180]))
# (array([1512373620]), array([1512255180]))
# (array([1512373680]), array([1512255180]))
# (array([1512373740]), array([1512255180]))
# (array([1512373800]), array([1512255180]))
# (array([1512373860]), array([1512255180]))
# (array([1512373920]), array([1512255180]))
# (array([1512373980]), array([1512255180]))
# (array([1512374040]), array([1512255180]))
# (array([1512374100]), array([1512255180]))
# (array([1512374160]), array([1512255180]))
# (array([1512374220]), array([1512255180]))
# (array([1512374280]), array([1512255180]))
# (array([1512374340]), array([1512255180]))
# (array([1512374400]), array([1512255180]))
# (array([1512374460]), array([1512255180]))
# (array([1512374520]), array([1512255180]))
# (array([1512374580]), array([1512255180]))
# (array([1512374640]), array([1512255180]))
# (array([1512374700]), array([1512255180]))
# (array([1512374760]), array([1512255180]))
# (array([1512374820]), array([1512255180]))
# (array([1512374880]), array([1512255180]))
# (array([1512374940]), array([1512255180]))
# (array([1512375000]), array([1512255180]))
# (array([1512375060]), array([1512255180]))
# (array([1512375120]), array([1512255180]))
# (array([1512375180]), array([1512255180]))
# (array([1512375240]), array([1512255180]))
# (array([1512375300]), array([1512255180]))
# (array([1512375360]), array([1512255180]))
# (array([1512375420]), array([1512255180]))
# (array([1512375480]), array([1512255180]))
# (array([1512375540]), array([1512255180]))
# (array([1512375600]), array([1512255180]))
# (array([1512375660]), array([1512255180]))
# (array([1512375720]), array([1512255180]))
# (array([1512375780]), array([1512255180]))
# (array([1512375840]), array([1512255180]))
# (array([1512375900]), array([1512255180]))
# (array([1512375960]), array([1512255180]))
# (array([1512376020]), array([1512255180]))
# (array([1512376080]), array([1512255180]))
# (array([1512376140]), array([1512255180]))
# (array([1512376200]), array([1512255180]))
# (array([1512376260]), array([1512255180]))
# (array([1512376320]), array([1512255180]))
# (array([1512376380]), array([1512255180]))
# (array([1512376440]), array([1512255180]))
# (array([1512376500]), array([1512255180]))
# (array([1512376560]), array([1512255180]))
# (array([1512376620]), array([1512255180]))
# (array([1512376680]), array([1512255180]))
# (array([1512376740]), array([1512255180]))
# (array([1512376800]), array([1512255180]))
# (array([1512376860]), array([1512255180]))
# (array([1512376920]), array([1512255180]))
# (array([1512376980]), array([1512255180]))
# (array([1512377040]), array([1512255180]))
# (array([1512377100]), array([1512255180]))
# (array([1512377160]), array([1512255180]))
# (array([1512377220]), array([1512255180]))
# (array([1512377280]), array([1512255180]))
# (array([1512377340]), array([1512255180]))
# (array([1512377400]), array([1512255180]))
# (array([1512377460]), array([1512255180]))
# (array([1512377520]), array([1512255180]))
# (array([1512377580]), array([1512255180]))
# (array([1512377640]), array([1512255180]))
# (array([1512377700]), array([1512255180]))
# (array([1512377760]), array([1512255180]))
# (array([1512377820]), array([1512255180]))
# (array([1512377880]), array([1512255180]))
# (array([1512377940]), array([1512255180]))
# (array([1512378000]), array([1512255180]))
# (array([1512378060]), array([1512255180]))
# (array([1512378120]), array([1512255180]))
# (array([1512378180]), array([1512255180]))
# (array([1512378240]), array([1512255180]))
# (array([1512378300]), array([1512255180]))
# (array([1512378360]), array([1512255180]))
# (array([1512378420]), array([1512255180]))
# (array([1512378480]), array([1512255180]))
# (array([1512378540]), array([1512255180]))
# (array([1512378600]), array([1512255180]))
# (array([1512378660]), array([1512255180]))
# (array([1512378720]), array([1512255180]))
# (array([1512378780]), array([1512255180]))
# (array([1512378840]), array([1512255180]))
# (array([1512378900]), array([1512255180]))
# (array([1512378960]), array([1512255180]))
# (array([1512379020]), array([1512255180]))
# (array([1512379080]), array([1512255180]))
# (array([1512379140]), array([1512255180]))
# (array([1512379200]), array([1512255180]))
# (array([1512379260]), array([1512255180]))
# (array([1512379320]), array([1512255180]))
# (array([1512379380]), array([1512255180]))
# (array([1512379440]), array([1512255180]))
# (array([1512379500]), array([1512255180]))
# (array([1512379560]), array([1512255180]))
# (array([1512379620]), array([1512255180]))
# (array([1512379680]), array([1512255180]))
# (array([1512379740]), array([1512255180]))
# (array([1512379800]), array([1512255180]))
# (array([1512379860]), array([1512255180]))
# (array([1512379920]), array([1512255180]))
# (array([1512379980]), array([1512255180]))
# (array([1512380040]), array([1512255180]))
# (array([1512380100]), array([1512255180]))
# (array([1512380160]), array([1512255180]))
# (array([1512380220]), array([1512255180]))
# (array([1512380280]), array([1512255180]))
# (array([1512380340]), array([1512255180]))
# (array([1512380400]), array([1512255180]))
# (array([1512380460]), array([1512255180]))
# (array([1512380520]), array([1512255180]))
# (array([1512380580]), array([1512255180]))
# (array([1512380640]), array([1512255180]))
# (array([1512380700]), array([1512255180]))
# (array([1512380760]), array([1512255180]))
# (array([1512380820]), array([1512255180]))
# (array([1512380880]), array([1512255180]))
# (array([1512380940]), array([1512255180]))
# (array([1512381000]), array([1512255180]))
# (array([1512381060]), array([1512255180]))
# (array([1512381120]), array([1512255180]))
# (array([1512381180]), array([1512255180]))
# (array([1512381240]), array([1512255180]))
# (array([1512381300]), array([1512255180]))
# (array([1512381360]), array([1512255180]))
# (array([1512381420]), array([1512255180]))
# (array([1512381480]), array([1512255180]))
# (array([1512381540]), array([1512255180]))
# (array([1512381600]), array([1512255180]))
# (array([1512381660]), array([1512255180]))
# (array([1512381720]), array([1512255180]))
# (array([1512381780]), array([1512255180]))
# (array([1512381840]), array([1512255180]))
# (array([1512381900]), array([1512255180]))
# (array([1512381960]), array([1512255180]))
# (array([1512382020]), array([1512255180]))
# (array([1512382080]), array([1512255180]))
# (array([1512382140]), array([1512255180]))
# (array([1512382200]), array([1512255180]))
# (array([1512382260]), array([1512255180]))
# (array([1512382320]), array([1512255180]))
# (array([1512382380]), array([1512255180]))
# (array([1512382440]), array([1512255180]))
# (array([1512382500]), array([1512255180]))
# (array([1512382560]), array([1512255180]))
# (array([1512382620]), array([1512255180]))
# (array([1512382680]), array([1512255180]))
# (array([1512382740]), array([1512255180]))
# (array([1512382800]), array([1512255180]))
# (array([1512382860]), array([1512255180]))
# (array([1512382920]), array([1512255180]))
# (array([1512382980]), array([1512255180]))
# (array([1512383040]), array([1512255180]))
# (array([1512383100]), array([1512255180]))
# (array([1512383160]), array([1512255180]))
# (array([1512383220]), array([1512255180]))
# (array([1512383280]), array([1512255180]))
# (array([1512383340]), array([1512255180]))
# (array([1512383400]), array([1512255180]))
# (array([1512383460]), array([1512255180]))
# (array([1512383520]), array([1512255180]))
# (array([1512383580]), array([1512255180]))
# (array([1512383640]), array([1512255180]))
# (array([1512383700]), array([1512255180]))
# (array([1512383760]), array([1512255180]))
# (array([1512383820]), array([1512255180]))
# (array([1512383880]), array([1512255180]))
# (array([1512383940]), array([1512255180]))
# (array([1512384000]), array([1512255180]))
# (array([1512384060]), array([1512255180]))
# (array([1512384120]), array([1512255180]))
# (array([1512384180]), array([1512255180]))
# (array([1512384240]), array([1512255180]))
# (array([1512384300]), array([1512255180]))
# (array([1512384360]), array([1512255180]))
# (array([1512384420]), array([1512255180]))
# (array([1512384480]), array([1512255180]))
# (array([1512384540]), array([1512255180]))
# (array([1512384600]), array([1512255180]))
# (array([1512384660]), array([1512255180]))
# (array([1512384720]), array([1512255180]))
# (array([1512384780]), array([1512255180]))
# (array([1512384840]), array([1512255180]))
# (array([1512384900]), array([1512255180]))
# (array([1512384960]), array([1512255180]))
# (array([1512385020]), array([1512255180]))
# (array([1512385080]), array([1512255180]))
# (array([1512385140]), array([1512255180]))
# (array([1512385200]), array([1512255180]))
# (array([1512385260]), array([1512255180]))
# (array([1512385320]), array([1512255180]))
# (array([1512385380]), array([1512255180]))
# (array([1512385440]), array([1512255180]))
# (array([1512385500]), array([1512255180]))
# (array([1512385560]), array([1512255180]))
# (array([1512385620]), array([1512255180]))
# (array([1512385680]), array([1512255180]))
# (array([1512385740]), array([1512255180]))
# (array([1512385800]), array([1512255180]))
# (array([1512385860]), array([1512255180]))
# (array([1512385920]), array([1512255180]))
# (array([1512385980]), array([1512255180]))
# (array([1512386040]), array([1512255180]))
# (array([1512386100]), array([1512255180]))
# (array([1512386160]), array([1512255180]))
# (array([1512386220]), array([1512255180]))
# (array([1512386280]), array([1512255180]))
# (array([1512386340]), array([1512255180]))

# %%
print(join_arr)
print(join_arr.shape)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [[1509721200 Timestamp('2017-11-03 15:00:00') 5244 ..., 51 26 51]
#  [1509721260 Timestamp('2017-11-03 15:01:00') 5201 ..., 51 26 51]
#  [1509721320 Timestamp('2017-11-03 15:02:00') 5168 ..., 51 26 51]
#  ...,
#  [1512255000 Timestamp('2017-12-02 22:50:00') 5305 ..., 56 31 56]
#  [1512255060 Timestamp('2017-12-02 22:51:00') 5243 ..., 56 31 56]
#  [1512255120 Timestamp('2017-12-02 22:52:00') 5264 ..., 56 31 56]]
# (42119, 42)

# %%
print(os_stat_unix_second_arr[i-emp])
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [1512255120]

# %%
temp_arr = np.append([os_stat_unix_second_arr[0]], [os_stat_arr[0]], axis = 1)
print(temp_arr)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [[1509721200 Timestamp('2017-11-03 15:00:00') 5244 6670 246592 241860
#   6117496 0.9596906969779793]]

# %%
temp_arr = [os_stat_arr[0]]
print(temp_arr)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [array([Timestamp('2017-11-03 15:00:00'), 5244, 6670, 246592, 241860,
#        6117496, 0.9596906969779793], dtype=object)]

# %%
#연습한거

print([os_stat_arr[0]])
print([[stat_arr[0][2]]])

temp_arr = np.append([os_stat_arr[0]], [[stat_arr[0][2]]], axis = 1)
temp_arr = np.append(temp_arr, [[stat_arr[0][2]]], axis = 1)

print(temp_arr)

join_arr4 = temp_arr
join_arr4 = np.append(join_arr4, temp_arr, axis =0)
print(join_arr4)
#join_arr4 = np.append(join_arr4, temp_arr,axis=0)
#join_arr4 = np.append(join_arr4, temp_arr,axis=0)
#join_arr4 = np.append(join_arr4, temp_arr,axis=0)

print(join_arr4)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [array([Timestamp('2017-11-03 15:00:00'), 5244, 6670, 246592, 241860,
#        6117496, 0.9596906969779793], dtype=object)]
# [[51]]
# [[Timestamp('2017-11-03 15:00:00') 5244 6670 246592 241860 6117496
#   0.9596906969779793 51 51]]
# [[Timestamp('2017-11-03 15:00:00') 5244 6670 246592 241860 6117496
#   0.9596906969779793 51 51]
#  [Timestamp('2017-11-03 15:00:00') 5244 6670 246592 241860 6117496
#   0.9596906969779793 51 51]]
# [[Timestamp('2017-11-03 15:00:00') 5244 6670 246592 241860 6117496
#   0.9596906969779793 51 51]
#  [Timestamp('2017-11-03 15:00:00') 5244 6670 246592 241860 6117496
#   0.9596906969779793 51 51]]

# %%
result_arr = [[]]
emp = 0

# 1512255120 = 2017-12-02 22:52:00

length = (1512255120-1509721200)/60 +1

for i in range(length):
  
  join_time = join_arr[i-emp][0]
  time = timerange_arr[i]
  
  if(time == join_time):
    if(time == 1509721200):
      result_arr = [np.append(timerange_arr[i], join_arr[i-emp])]
    else:  
      row_arr = [np.append(timerange_arr[i], join_arr[i-emp])]
      result_arr = np.append(result_arr, row_arr, axis = 0)
  else:
    emp+=1
    row_arr = [np.append(timerange_arr[i], join_arr[i-emp])]
    result_arr = np.append(result_arr, row_arr, axis = 0)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
result_arr = [np.append(timerange_arr[0], join_arr[0])]
row_arr = [np.append(timerange_arr[0], join_arr[0])]
result_arr = np.append(result_arr, row_arr, axis = 0)
print(result_arr)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [[1509721200.0 1509721200 Timestamp('2017-11-03 15:00:00') 5244 6670 246592
#   241860 6117496 0.9596906969779793 51 86 887656 163 2221 1650312 4662936
#   926 69869335 0 0 170689 14 227787 473547 59 59 38 11145625 7 157952
#   11303577 1960 1806 18183782 0 14952 249304 48 0 25 51 26 51]
#  [1509721200.0 1509721200 Timestamp('2017-11-03 15:00:00') 5244 6670 246592
#   241860 6117496 0.9596906969779793 51 86 887656 163 2221 1650312 4662936
#   926 69869335 0 0 170689 14 227787 473547 59 59 38 11145625 7 157952
#   11303577 1960 1806 18183782 0 14952 249304 48 0 25 51 26 51]]

# %%
print(result_arr)
print(result_arr.shape)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [[1509721200.0 1509721200 Timestamp('2017-11-03 15:00:00') ..., 51 26 51]
#  [1509721260.0 1509721260 Timestamp('2017-11-03 15:01:00') ..., 51 26 51]
#  [1509721320.0 1509721320 Timestamp('2017-11-03 15:02:00') ..., 51 26 51]
#  ...,
#  [1512255000.0 1512255000 Timestamp('2017-12-02 22:50:00') ..., 56 31 56]
#  [1512255060.0 1512255060 Timestamp('2017-12-02 22:51:00') ..., 56 31 56]
#  [1512255120.0 1512255120 Timestamp('2017-12-02 22:52:00') ..., 56 31 56]]
# (42233, 43)

# %%
result_df = pd.DataFrame(result_arr)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
result_df.columns = ['UNIX_time','useless', 'timestamp','cpu_usage', 'max_cpu_usage', 'free_memory', 'min_free_memory', 'total_memory', 'use_memory_rate', 'stat_value_1', 'stat_value_2', 'stat_value_3', 'stat_value_4', 'stat_value_5', 'stat_value_6', 'stat_value_7', 'stat_value_8', 'stat_value_9', 'stat_value_10', 'stat_value_11', 'stat_value_12', 'stat_value_13', 'stat_value_14', 'stat_value_15', 'stat_value_16', 'stat_value_17', 'stat_value_18', 'stat_value_19', 'stat_value_20', 'stat_value_21', 'stat_value_22', 'stat_value_23', 'stat_value_24', 'stat_value_25', 'stat_value_26', 'stat_value_27', 'stat_value_28', 'stat_value_29', 'stat_value_30', 'stat_value_31', 'stat_value_32', 'stat_value_33', 'stat_value_34']
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
print(result_df)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
# 17                3             0            25            51            26
# 18                3             0            25            51            26
# 19                3             0            25            51            26
# 20                4             0            25            51            26
# 21                3             0            25            51            26
# 22               15             0            25            51            26
# 23                3             0            25            51            26
# 24               19             0            25            51            26
# 25                3             0            25            51            26
# 26                3             0            25            51            26
# 27                3             0            25            51            26
# 28                4             0            25            51            26
# 29                3             0            25            51            26
# ...             ...           ...           ...           ...           ...
# 42203             7             0            25            56            31
# 42204             8             0            25            56            31
# 42205             7             0            25            56            31
# 42206             7             0            25            56            31
# 42207             9             0            25            56            31
# 42208             7             0            25            56            31
# 42209             8             0            25            56            31
# 42210            18             0            25            56            31
# 42211             7             0            25            56            31
# 42212            20             0            25            56            31
# 42213             7             0            25            56            31
# 42214             8             0            25            56            31
# 42215             7             0            25            56            31
# 42216             7             0            25            56            31
# 42217            10             0            25            56            31
# 42218             7             0            25            56            31
# 42219             7             0            25            56            31
# 42220            17             0            25            56            31
# 42221             7             0            25            56            31
# 42222            20             0            25            56            31
# 42223             7             0            25            55            30
# 42224             8             0            25            56            31
# 42225             7             0            25            56            31
# 42226             7             0            25            56            31
# 42227             9             0            25            56            31
# 42228             7             0            25            56            31
# 42229             7             0            25            56            31
# 42230            17             0            25            56            31
# 42231             7             0            25            56            31
# 42232            21             0            25            56            31
#
#       stat_value_34
# 0                51
# 1                51
# 2                51
# 3                51
# 4                51
# 5                51
# 6                51
# 7                51
# 8                51
# 9                51
# 10               51
# 11               51
# 12               51
# 13               51
# 14               51
# 15               51
# 16               51
# 17               51
# 18               51
# 19               51
# 20               51
# 21               51
# 22               51
# 23               51
# 24               51
# 25               51
# 26               51
# 27               51
# 28               51
# 29               51
# ...             ...
# 42203            56
# 42204            56
# 42205            56
# 42206            56
# 42207            56
# 42208            56
# 42209            56
# 42210            56
# 42211            56
# 42212            56
# 42213            56
# 42214            56
# 42215            56
# 42216            56
# 42217            56
# 42218            56
# 42219            56
# 42220            56
# 42221            56
# 42222            56
# 42223            55
# 42224            56
# 42225            56
# 42226            56
# 42227            56
# 42228            56
# 42229            56
# 42230            56
# 42231            56
# 42232            56
#
# [42233 rows x 42 columns]

# %%
#연습용

result_arr = [join_arr[0]]
result_arr = np.append(result_arr, [join_arr[1]], axis = 0)
result_arr = np.append(result_arr, [join_arr[2]], axis = 0)
print(result_arr)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [[1509721200 Timestamp('2017-11-03 15:00:00') 5244 6670 246592 241860
#   6117496 0.9596906969779793 51 86 887656 163 2221 1650312 4662936 926
#   69869335 0 0 170689 14 227787 473547 59 59 38 11145625 7 157952 11303577
#   1960 1806 18183782 0 14952 249304 48 0 25 51 26 51]
#  [1509721260 Timestamp('2017-11-03 15:01:00') 5201 5720 246007 241844
#   6117496 0.9597863243392395 51 86 900186 163 23 1654267 4660257 908
#   54933906 0 0 70131 14 139314 -93338 25 25 5 88883 2 39168 128051 21 16
#   190873 0 269 18 3 0 25 51 26 51]
#  [1509721320 Timestamp('2017-11-03 15:02:00') 5168 5460 245579 241372
#   6117496 0.9598562876052554 51 86 872536 157 92 1618310 4623398 833
#   145042783 0 0 168123 14 188466 381797 31 31 5 95846 3 43340 139187 77 32
#   758169 0 6149 34 14 0 25 51 26 51]]

# %% [markdown]
# # 일단 빅쿼리에 저장시키자

# %%
result_df.to_gbq('ods_im5.os_and_stat2', 'exem-191100', if_exists = 'replace')
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# Streaming Insert is 23% Complete
# GenericGBQExceptionTraceback (most recent call last)
# <ipython-input-130-d0158d4841fc> in <module>()
# ----> 1 result_df.to_gbq('ods_im5.os_and_stat2', 'exem-191100', if_exists = 'replace')
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in to_gbq(self, destination_table, project_id, chunksize, verbose, reauth, if_exists, private_key)
#     939         return gbq.to_gbq(self, destination_table, project_id=project_id,
#     940                           chunksize=chunksize, verbose=verbose, reauth=reauth,
# --> 941                           if_exists=if_exists, private_key=private_key)
#     942
#     943     @classmethod
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/gbq.pyc in to_gbq(dataframe, destination_table, project_id, chunksize, verbose, reauth, if_exists, private_key)
#     831         table.create(table_id, table_schema)
#     832
# --> 833     connector.load_data(dataframe, dataset_id, table_id, chunksize)
#     834
#     835
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/gbq.pyc in load_data(self, dataframe, dataset_id, table_id, chunksize)
#     520                         body=body).execute()
#     521                 except HttpError as ex:
# --> 522                     self.process_http_error(ex)
#     523
#     524                 # For streaming inserts, even if you receive a success HTTP
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/gbq.pyc in process_http_error(ex)
#     350
#     351                 raise GenericGBQException(
# --> 352                     "Reason: {0}, Message: {1}".format(reason, message))
#     353
#     354         raise GenericGBQException(errors)
#
# GenericGBQException: Reason: badRequest, Message: Request payload size exceeds the limit: 10485760 bytes.

# %% [markdown]
# ## 어제는 되고 오늘은 안되고... column 하나 추가한거에 대한 사이즈 증가분이 그렇게 critical 한가?

# %%
# %%bq query --name os_and_stat
# SELECT *
# FROM `exem-191100.ods_im5.os_and_stat`
# ORDER BY utf_time
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query os_and_stat
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_ESyjV46rF5knH8IW2d6GV6xxiMpw

# %%
join1_sql = 'SELECT * FROM `exem-191100.ods_im5.os_and_stat`ORDER BY utf_time'

join1_query = bq.Query(join1_sql)

join1_df = join1_query.execute(output_options = bq.QueryOutput.dataframe()).result()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
join1_arr = join1_df.as_matrix()
print(join1_arr)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [['1509721200' '2017-11-03T15:00:00Z' '5244' ..., '51' '26' '51']
#  ['1509721260' '2017-11-03T15:01:00Z' '5201' ..., '51' '26' '51']
#  ['1509721320' '2017-11-03T15:02:00Z' '5168' ..., '51' '26' '51']
#  ...,
#  ['1512255000' '2017-12-02T22:50:00Z' '5305' ..., '56' '31' '56']
#  ['1512255060' '2017-12-02T22:51:00Z' '5243' ..., '56' '31' '56']
#  ['1512255120' '2017-12-02T22:52:00Z' '5264' ..., '56' '31' '56']]

# %%
# %%bq query --name wait
# SELECT UNIX_SECONDS(time) as unix_time, time, event_id, wait_time
# FROM `exem-191100.ods_im5.xapm_db_wait` as t_wait
# WHERE db_id = 6 and EXISTS(
#   SELECT *
#   FROM(
#     SELECT event_id, MIN(wait_time) as min_wait, MAX(wait_time) as max_wait
#     FROM `exem-191100.ods_im5.xapm_db_wait`
#     WHERE db_id = 6
#     GROUP BY event_id
#     HAVING ( min_wait <> 0 and max_wait <> 0)
#     ) as t_comp
#   WHERE t_wait.event_id = t_comp.event_id
#   )
# ORDER BY time, event_id
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query wait --count 1000
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_Wj2zGDtZ_b_H61OkoJOIo3DKI-vS

# %%
wait_sql = 'SELECT UNIX_SECONDS(time) as unix_time, time, event_id, wait_time FROM `exem-191100.ods_im5.xapm_db_wait` as t_wait WHERE db_id = 6 and EXISTS( SELECT * FROM( SELECT event_id, MIN(wait_time) as min_wait, MAX(wait_time) as max_wait FROM `exem-191100.ods_im5.xapm_db_wait` WHERE db_id = 6 GROUP BY event_id HAVING ( min_wait <> 0 and max_wait <> 0) ) as t_comp WHERE t_wait.event_id = t_comp.event_id ) ORDER BY time, event_id'

wait_query = bq.Query(wait_sql)

wait_df = wait_query.execute(output_options = bq.QueryOutput.dataframe()).result()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
wait_arr = wait_df.as_matrix()
print(wait_arr)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [[1509721200 Timestamp('2017-11-03 15:00:00') 1 300]
#  [1509721200 Timestamp('2017-11-03 15:00:00') 7 3286]
#  [1509721200 Timestamp('2017-11-03 15:00:00') 74 595]
#  ...,
#  [1512391980 Timestamp('2017-12-04 12:53:00') 378 104]
#  [1512391980 Timestamp('2017-12-04 12:53:00') 379 320]
#  [1512391980 Timestamp('2017-12-04 12:53:00') 380 320]]

# %%
prev = 1509721140
empty = 0

for i in range(wait_arr.shape[0]):
  if(i%11 == 0):
    now = wait_arr[i][0]
    if( (now-prev) != 60):
      print(prev, now)
      empty += (now-prev)/60 - 1
    prev = now
print(empty)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# (1509931800, 1509931863)
# (1509931923, 1509931980)
# (1510218840, 1510218960)
# (1510353180, 1510353243)
# (1510353243, 1510353300)
# (1510633980, 1510634460)
# (1510747380, 1510747500)
# (1510804440, 1510804680)
# (1510828620, 1510829040)
# (1510842540, 1510842960)
# (1511240280, 1511240460)
# (1511267280, 1511267520)
# (1511409660, 1511409780)
# (1511410020, 1511410440)
# (1511410560, 1511410680)
# (1511410680, 1511411040)
# (1511411100, 1511411280)
# (1511412360, 1511412480)
# (1511412780, 1511412900)
# (1511413020, 1511413320)
# (1511413560, 1511413680)
# (1511415420, 1511415600)
# (1511415600, 1511415720)
# (1511415840, 1511415960)
# (1511416200, 1511416320)
# (1511416680, 1511416860)
# (1511417880, 1511418960)
# (1511421600, 1511421720)
# (1511421720, 1511423760)
# (1511436420, 1511436540)
# (1511506440, 1511506620)
# (1511510460, 1511510580)
# (1511511300, 1511511420)
# (1511881800, 1511881920)
# (1511883180, 1511883300)
# (1511883480, 1511883600)
# (1511884620, 1511884740)
# 116

# %%
for i in range(wait_arr.shape[0]):
  if( (wait_arr[i][0])%60 != 0 ):
    wait_arr[i][0] = wait_arr[i][0]-3
    print(wait_arr[i][0])
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# 1509931860
# 1509931860
# 1509931860
# 1509931860
# 1509931860
# 1509931860
# 1509931860
# 1509931860
# 1509931860
# 1509931860
# 1509931860
# 1509931920
# 1509931920
# 1509931920
# 1509931920
# 1509931920
# 1509931920
# 1509931920
# 1509931920
# 1509931920
# 1509931920
# 1509931920
# 1510353240
# 1510353240
# 1510353240
# 1510353240
# 1510353240
# 1510353240
# 1510353240
# 1510353240
# 1510353240
# 1510353240
# 1510353240

# %%
print(wait_arr.shape)
print(wait_arr.shape[0]/11)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# (488356, 4)
# 44396

# %%
join1_arr = result_arr
join2_arr = [[]]
emp = 0
suc = 0

for i in range(int(join1_arr.shape[0])):
  join1_time = join1_arr[i][0]
  wait_time = wait_arr[(i-emp)*11][0]
  
  if(i<10000):
    print(int(join1_time), wait_time)
  if(int(join1_time) == wait_time):
    suc+=1
    
    temp_arr = [join1_arr[i]]
    
    for j in range(11): 
      temp_arr = np.append(temp_arr, [[wait_arr[(i-emp)*11+j][3]]], axis=1)
    
    if(i == 0):
      join2_arr = temp_arr
    else:
      join2_arr = np.append(join2_arr, temp_arr, axis = 0)
  else:
    emp+=1
    
print(suc)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# (1509721200, 1509721200)
# (1509721260, 1509721260)
# (1509721320, 1509721320)
# (1509721380, 1509721380)
# (1509721440, 1509721440)
# (1509721500, 1509721500)
# (1509721560, 1509721560)
# (1509721620, 1509721620)
# (1509721680, 1509721680)
# (1509721740, 1509721740)
# (1509721800, 1509721800)
# (1509721860, 1509721860)
# (1509721920, 1509721920)
# (1509721980, 1509721980)
# (1509722040, 1509722040)
# (1509722100, 1509722100)
# (1509722160, 1509722160)
# (1509722220, 1509722220)
# (1509722280, 1509722280)
# (1509722340, 1509722340)
# (1509722400, 1509722400)
# (1509722460, 1509722460)
# (1509722520, 1509722520)
# (1509722580, 1509722580)
# (1509722640, 1509722640)
# (1509722700, 1509722700)
# (1509722760, 1509722760)
# (1509722820, 1509722820)
# (1509722880, 1509722880)
# (1509722940, 1509722940)
# (1509723000, 1509723000)
# (1509723060, 1509723060)
# (1509723120, 1509723120)
# (1509723180, 1509723180)
# (1509723240, 1509723240)
# (1509723300, 1509723300)
# (1509723360, 1509723360)
# (1509723420, 1509723420)
# (1509723480, 1509723480)
# (1509723540, 1509723540)
# (1509723600, 1509723600)
# (1509723660, 1509723660)
# (1509723720, 1509723720)
# (1509723780, 1509723780)
# (1509723840, 1509723840)
# (1509723900, 1509723900)
# (1509723960, 1509723960)
# (1509724020, 1509724020)
# (1509724080, 1509724080)
# (1509724140, 1509724140)
# (1509724200, 1509724200)
# (1509724260, 1509724260)
# (1509724320, 1509724320)
# (1509724380, 1509724380)
# (1509724440, 1509724440)
# (1509724500, 1509724500)
# (1509724560, 1509724560)
# (1509724620, 1509724620)
# (1509724680, 1509724680)
# (1509724740, 1509724740)
# (1509724800, 1509724800)
# (1509724860, 1509724860)
# (1509724920, 1509724920)
# (1509724980, 1509724980)
# (1509725040, 1509725040)
# (1509725100, 1509725100)
# (1509725160, 1509725160)
# (1509725220, 1509725220)
# (1509725280, 1509725280)
# (1509725340, 1509725340)
# (1509725400, 1509725400)
# (1509725460, 1509725460)
# (1509725520, 1509725520)
# (1509725580, 1509725580)
# (1509725640, 1509725640)
# (1509725700, 1509725700)
# (1509725760, 1509725760)
# (1509725820, 1509725820)
# (1509725880, 1509725880)
# (1509725940, 1509725940)
# (1509726000, 1509726000)
# (1509726060, 1509726060)
# (1509726120, 1509726120)
# (1509726180, 1509726180)
# (1509726240, 1509726240)
# (1509726300, 1509726300)
# (1509726360, 1509726360)
# (1509726420, 1509726420)
# (1509726480, 1509726480)
# (1509726540, 1509726540)
# (1509726600, 1509726600)
# (1509726660, 1509726660)
# (1509726720, 1509726720)
# (1509726780, 1509726780)
# (1509726840, 1509726840)
# (1509726900, 1509726900)
# (1509759720, 1509759720)
# (1509759780, 1509759780)
# (1509759840, 1509759840)
# (1509759900, 1509759900)
# (1509759960, 1509759960)
# (1509760020, 1509760020)
# (1509760080, 1509760080)
# (1509760140, 1509760140)
# (1509760200, 1509760200)
# (1509760260, 1509760260)
# (1509760320, 1509760320)
# (1509760380, 1509760380)
# (1509760440, 1509760440)
# (1509760500, 1509760500)
# (1509760560, 1509760560)
# (1509760620, 1509760620)
# (1509760680, 1509760680)
# (1509760740, 1509760740)
# (1509760800, 1509760800)
# (1509760860, 1509760860)
# (1509760920, 1509760920)
# (1509760980, 1509760980)
# (1509761040, 1509761040)
# (1509761100, 1509761100)
# (1509761160, 1509761160)
# (1509761220, 1509761220)
# (1509761280, 1509761280)
# (1509761340, 1509761340)
# (1509761400, 1509761400)
# (1509761460, 1509761460)
# (1509761520, 1509761520)
# (1509761580, 1509761580)
# (1509761640, 1509761640)
# (1509761700, 1509761700)
# (1509761760, 1509761760)
# (1509761820, 1509761820)
# (1509761880, 1509761880)
# (1509761940, 1509761940)
# (1509762000, 1509762000)
# (1509762060, 1509762060)
# (1509762120, 1509762120)
# (1509762180, 1509762180)
# (1509762240, 1509762240)
# (1509762300, 1509762300)
# (1509762360, 1509762360)
# (1509762420, 1509762420)
# (1509762480, 1509762480)
# (1509762540, 1509762540)
# (1509762600, 1509762600)
# (1509762660, 1509762660)
# (1509762720, 1509762720)
# (1509762780, 1509762780)
# (1509762840, 1509762840)
# (1509762900, 1509762900)
# (1509762960, 1509762960)
# (1509763020, 1509763020)
# (1509763080, 1509763080)
# (1509763140, 1509763140)
# (1509763200, 1509763200)
# (1509763260, 1509763260)
# (1509763320, 1509763320)
# (1509763380, 1509763380)
# (1509763440, 1509763440)
# (1509763500, 1509763500)
# (1509763560, 1509763560)
# (1509763620, 1509763620)
# (1509763680, 1509763680)
# (1509763740, 1509763740)
# (1509763800, 1509763800)
# (1509763860, 1509763860)
# (1509763920, 1509763920)
# (1509763980, 1509763980)
# (1509764040, 1509764040)
# (1509764100, 1509764100)
# (1509764160, 1509764160)
# (1509764220, 1509764220)
# (1509764280, 1509764280)
# (1509764340, 1509764340)
# (1509764400, 1509764400)
# (1509764460, 1509764460)
# (1509764520, 1509764520)
# (1509764580, 1509764580)
# (1509764640, 1509764640)
# (1509764700, 1509764700)
# (1509764760, 1509764760)
# (1509764820, 1509764820)
# (1509764880, 1509764880)
# (1509764940, 1509764940)
# (1509765000, 1509765000)
# (1509765060, 1509765060)
# (1509765120, 1509765120)
# (1509765180, 1509765180)
# (1509765240, 1509765240)
# (1509765300, 1509765300)
# (1509765360, 1509765360)
# (1509765420, 1509765420)
# (1509765480, 1509765480)
# (1509765540, 1509765540)
# (1509765600, 1509765600)
# (1509765660, 1509765660)
# (1509765720, 1509765720)
# (1509765780, 1509765780)
# (1509765840, 1509765840)
# (1509765900, 1509765900)
# (1509765960, 1509765960)
# (1509766020, 1509766020)
# (1509766080, 1509766080)
# (1509766140, 1509766140)
# (1509766200, 1509766200)
# (1509766260, 1509766260)
# (1509779400, 1509779400)
# (1509779460, 1509779460)
# (1509779520, 1509779520)
# (1509779580, 1509779580)
# (1509779640, 1509779640)
# (1509779700, 1509779700)
# (1509779760, 1509779760)
# (1509779820, 1509779820)
# (1509779880, 1509779880)
# (1509779940, 1509779940)
# (1509780000, 1509780000)
# (1509780060, 1509780060)
# (1509780120, 1509780120)
# (1509780180, 1509780180)
# (1509780240, 1509780240)
# (1509780300, 1509780300)
# (1509780360, 1509780360)
# (1509780420, 1509780420)
# (1509780480, 1509780480)
# (1509780540, 1509780540)
# (1509780600, 1509780600)
# (1509780660, 1509780660)
# (1509780720, 1509780720)
# (1509780780, 1509780780)
# (1509780840, 1509780840)
# (1509780900, 1509780900)
# (1509780960, 1509780960)
# (1509781020, 1509781020)
# (1509781080, 1509781080)
# (1509781140, 1509781140)
# (1509781200, 1509781200)
# (1509781260, 1509781260)
# (1509781320, 1509781320)
# (1509781380, 1509781380)
# (1509781440, 1509781440)
# (1509781500, 1509781500)
# (1509781560, 1509781560)
# (1509781620, 1509781620)
# (1509781680, 1509781680)
# (1509781740, 1509781740)
# (1509781800, 1509781800)
# (1509781860, 1509781860)
# (1509781920, 1509781920)
# (1509781980, 1509781980)
# (1509782040, 1509782040)
# (1509782100, 1509782100)
# (1509782160, 1509782160)
# (1509782220, 1509782220)
# (1509782280, 1509782280)
# (1509782340, 1509782340)
# (1509782400, 1509782400)
# (1509782460, 1509782460)
# (1509782520, 1509782520)
# (1509782580, 1509782580)
# (1509782640, 1509782640)
# (1509782700, 1509782700)
# (1509782760, 1509782760)
# (1509782820, 1509782820)
# (1509782880, 1509782880)
# (1509782940, 1509782940)
# (1509783000, 1509783000)
# (1509783060, 1509783060)
# (1509783120, 1509783120)
# (1509783180, 1509783180)
# (1509783240, 1509783240)
# (1509783300, 1509783300)
# (1509783360, 1509783360)
# (1509783420, 1509783420)
# (1509783480, 1509783480)
# (1509783540, 1509783540)
# (1509783600, 1509783600)
# (1509783660, 1509783660)
# (1509783720, 1509783720)
# (1509783780, 1509783780)
# (1509783840, 1509783840)
# (1509783900, 1509783900)
# (1509783960, 1509783960)
# (1509784020, 1509784020)
# (1509784080, 1509784080)
# (1509784140, 1509784140)
# (1509784200, 1509784200)
# (1509784260, 1509784260)
# (1509784320, 1509784320)
# (1509784380, 1509784380)
# (1509784440, 1509784440)
# (1509784500, 1509784500)
# (1509784560, 1509784560)
# (1509784620, 1509784620)
# (1509784680, 1509784680)
# (1509784740, 1509784740)
# (1509784800, 1509784800)
# (1509784860, 1509784860)
# (1509784920, 1509784920)
# (1509784980, 1509784980)
# (1509785040, 1509785040)
# (1509785100, 1509785100)
# (1509785160, 1509785160)
# (1509785220, 1509785220)
# (1509785280, 1509785280)
# (1509785340, 1509785340)
# (1509785400, 1509785400)
# (1509785460, 1509785460)
# (1509785520, 1509785520)
# (1509785580, 1509785580)
# (1509785640, 1509785640)
# (1509785700, 1509785700)
# (1509785760, 1509785760)
# (1509785820, 1509785820)
# (1509785880, 1509785880)
# (1509818760, 1509818760)
# (1509818820, 1509818820)
# (1509818880, 1509818880)
# (1509818940, 1509818940)
# (1509819000, 1509819000)
# (1509819060, 1509819060)
# (1509819120, 1509819120)
# (1509819180, 1509819180)
# (1509819240, 1509819240)
# (1509819300, 1509819300)
# (1509819360, 1509819360)
# (1509819420, 1509819420)
# (1509819480, 1509819480)
# (1509819540, 1509819540)
# (1509819600, 1509819600)
# (1509819660, 1509819660)
# (1509819720, 1509819720)
# (1509819780, 1509819780)
# (1509819840, 1509819840)
# (1509819900, 1509819900)
# (1509819960, 1509819960)
# (1509820020, 1509820020)
# (1509820080, 1509820080)
# (1509820140, 1509820140)
# (1509820200, 1509820200)
# (1509820260, 1509820260)
# (1509820320, 1509820320)
# (1509820380, 1509820380)
# (1509820440, 1509820440)
# (1509820500, 1509820500)
# (1509820560, 1509820560)
# (1509820620, 1509820620)
# (1509820680, 1509820680)
# (1509820740, 1509820740)
# (1509820800, 1509820800)
# (1509820860, 1509820860)
# (1509820920, 1509820920)
# (1509820980, 1509820980)
# (1509821040, 1509821040)
# (1509821100, 1509821100)
# (1509821160, 1509821160)
# (1509821220, 1509821220)
# (1509821280, 1509821280)
# (1509821340, 1509821340)
# (1509821400, 1509821400)
# (1509821460, 1509821460)
# (1509821520, 1509821520)
# (1509821580, 1509821580)
# (1509821640, 1509821640)
# (1509821700, 1509821700)
# (1509821760, 1509821760)
# (1509821820, 1509821820)
# (1509821880, 1509821880)
# (1509821940, 1509821940)
# (1509822000, 1509822000)
# (1509822060, 1509822060)
# (1509822120, 1509822120)
# (1509822180, 1509822180)
# (1509822240, 1509822240)
# (1509822300, 1509822300)
# (1509822360, 1509822360)
# (1509822420, 1509822420)
# (1509822480, 1509822480)
# (1509822540, 1509822540)
# (1509822600, 1509822600)
# (1509822660, 1509822660)
# (1509822720, 1509822720)
# (1509822780, 1509822780)
# (1509822840, 1509822840)
# (1509822900, 1509822900)
# (1509822960, 1509822960)
# (1509823020, 1509823020)
# (1509823080, 1509823080)
# (1509823140, 1509823140)
# (1509823200, 1509823200)
# (1509823260, 1509823260)
# (1509823320, 1509823320)
# (1509823380, 1509823380)
# (1509823440, 1509823440)
# (1509823500, 1509823500)
# (1509823560, 1509823560)
# (1509823620, 1509823620)
# (1509823680, 1509823680)
# (1509823740, 1509823740)
# (1509823800, 1509823800)
# (1509823860, 1509823860)
# (1509823920, 1509823920)
# (1509823980, 1509823980)
# (1509824040, 1509824040)
# (1509824100, 1509824100)
# (1509824160, 1509824160)
# (1509824220, 1509824220)
# (1509824280, 1509824280)
# (1509824340, 1509824340)
# (1509824400, 1509824400)
# (1509824460, 1509824460)
# (1509824520, 1509824520)
# (1509824580, 1509824580)
# (1509824640, 1509824640)
# (1509824700, 1509824700)
# (1509824760, 1509824760)
# (1509824820, 1509824820)
# (1509824880, 1509824880)
# (1509824940, 1509824940)
# (1509825000, 1509825000)
# (1509825060, 1509825060)
# (1509825120, 1509825120)
# (1509825180, 1509825180)
# (1509825240, 1509825240)
# (1509831840, 1509831840)
# (1509831900, 1509831900)
# (1509831960, 1509831960)
# (1509832020, 1509832020)
# (1509832080, 1509832080)
# (1509832140, 1509832140)
# (1509832200, 1509832200)
# (1509832260, 1509832260)
# (1509832320, 1509832320)
# (1509832380, 1509832380)
# (1509832440, 1509832440)
# (1509832500, 1509832500)
# (1509832560, 1509832560)
# (1509832620, 1509832620)
# (1509832680, 1509832680)
# (1509832740, 1509832740)
# (1509832800, 1509832800)
# (1509832860, 1509832860)
# (1509832920, 1509832920)
# (1509832980, 1509832980)
# (1509833040, 1509833040)
# (1509833100, 1509833100)
# (1509833160, 1509833160)
# (1509833220, 1509833220)
# (1509833280, 1509833280)
# (1509833340, 1509833340)
# (1509833400, 1509833400)
# (1509833460, 1509833460)
# (1509833520, 1509833520)
# (1509833580, 1509833580)
# (1509833640, 1509833640)
# (1509833700, 1509833700)
# (1509833760, 1509833760)
# (1509833820, 1509833820)
# (1509833880, 1509833880)
# (1509833940, 1509833940)
# (1509834000, 1509834000)
# (1509834060, 1509834060)
# (1509834120, 1509834120)
# (1509834180, 1509834180)
# (1509834240, 1509834240)
# (1509834300, 1509834300)
# (1509834360, 1509834360)
# (1509834420, 1509834420)
# (1509834480, 1509834480)
# (1509834540, 1509834540)
# (1509834600, 1509834600)
# (1509834660, 1509834660)
# (1509834720, 1509834720)
# (1509834780, 1509834780)
# (1509834840, 1509834840)
# (1509834900, 1509834900)
# (1509834960, 1509834960)
# (1509835020, 1509835020)
# (1509835080, 1509835080)
# (1509835140, 1509835140)
# (1509835200, 1509835200)
# (1509835260, 1509835260)
# (1509835320, 1509835320)
# (1509835380, 1509835380)
# (1509835440, 1509835440)
# (1509835500, 1509835500)
# (1509835560, 1509835560)
# (1509835620, 1509835620)
# (1509835680, 1509835680)
# (1509835740, 1509835740)
# ...
# (1510282860, 1510282860)
# (1510282920, 1510282920)
# (1510282980, 1510282980)
# (1510283040, 1510283040)
# (1510283100, 1510283100)
# (1510283160, 1510283160)
# (1510283220, 1510283220)
# (1510283280, 1510283280)
# (1510283340, 1510283340)
# (1510283400, 1510283400)
# (1510283460, 1510283460)
# (1510283520, 1510283520)
# (1510283580, 1510283580)
# (1510283640, 1510283640)
# (1510283700, 1510283700)
# (1510283760, 1510283760)
# (1510283820, 1510283820)
# (1510283880, 1510283880)
# (1510283940, 1510283940)
# (1510284000, 1510284000)
# (1510284060, 1510284060)
# (1510284120, 1510284120)
# (1510284180, 1510284180)
# (1510284240, 1510284240)
# (1510284300, 1510284300)
# (1510284360, 1510284360)
# (1510284420, 1510284420)
# (1510284480, 1510284480)
# (1510284540, 1510284540)
# (1510284600, 1510284600)
# (1510284660, 1510284660)
# (1510284720, 1510284720)
# (1510284780, 1510284780)
# (1510284840, 1510284840)
# (1510284900, 1510284900)
# (1510284960, 1510284960)
# (1510285020, 1510285020)
# (1510285080, 1510285080)
# (1510285140, 1510285140)
# (1510285200, 1510285200)
# (1510285260, 1510285260)
# (1510285320, 1510285320)
# (1510285380, 1510285380)
# (1510318200, 1510318200)
# (1510318260, 1510318260)
# (1510318320, 1510318320)
# (1510318380, 1510318380)
# (1510318440, 1510318440)
# (1510318500, 1510318500)
# (1510318560, 1510318560)
# (1510318620, 1510318620)
# (1510318680, 1510318680)
# (1510318740, 1510318740)
# (1510318800, 1510318800)
# (1510318860, 1510318860)
# (1510318920, 1510318920)
# (1510318980, 1510318980)
# (1510319040, 1510319040)
# (1510319100, 1510319100)
# (1510319160, 1510319160)
# (1510319220, 1510319220)
# (1510319280, 1510319280)
# (1510319340, 1510319340)
# (1510319400, 1510319400)
# (1510319460, 1510319460)
# (1510319520, 1510319520)
# (1510319580, 1510319580)
# (1510319640, 1510319640)
# (1510319700, 1510319700)
# (1510319760, 1510319760)
# (1510319820, 1510319820)
# (1510319880, 1510319880)
# (1510319940, 1510319940)
# (1510320000, 1510320000)
# (1510320060, 1510320060)
# (1510320120, 1510320120)
# (1510320180, 1510320180)
# (1510320240, 1510320240)
# (1510320300, 1510320300)
# (1510320360, 1510320360)
# (1510320420, 1510320420)
# (1510320480, 1510320480)
# (1510320540, 1510320540)
# (1510320600, 1510320600)
# (1510320660, 1510320660)
# (1510320720, 1510320720)
# (1510320780, 1510320780)
# (1510320840, 1510320840)
# (1510320900, 1510320900)
# (1510320960, 1510320960)
# (1510321020, 1510321020)
# (1510321080, 1510321080)
# (1510321140, 1510321140)
# 42115

# %%
print(join2_arr)
print(join2_arr.shape)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [[1509721200.0 1509721200 Timestamp('2017-11-03 15:00:00') ..., 96 320 320]
#  [1509721260.0 1509721260 Timestamp('2017-11-03 15:01:00') ..., 99 300 300]
#  [1509721320.0 1509721320 Timestamp('2017-11-03 15:02:00') ..., 98 300 300]
#  ...,
#  [1512255000.0 1512255000 Timestamp('2017-12-02 22:50:00') ..., 102 320 320]
#  [1512255060.0 1512255060 Timestamp('2017-12-02 22:51:00') ..., 96 300 300]
#  [1512255120.0 1512255120 Timestamp('2017-12-02 22:52:00') ..., 109 300 300]]
# (42115, 54)

# %%
output_arr = [[]]

for i in range(join2_arr.shape[0]):
  sum_time = 0
  for j in range(11):
    sum_time += join2_arr[i][43+j]
  
  if(i==1):
    output_arr = np.append([join2_arr[i-1]], [[sum_time]], axis = 1)
  if(i>1):
    temp_arr = np.append([join2_arr[i-1]], [[sum_time]], axis = 1)
    output_arr = np.append(output_arr, temp_arr, axis = 0)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
print(output_arr)
print(output_arr.shape)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [[1509721200.0 1509721200 Timestamp('2017-11-03 15:00:00') ..., 320 320
#   6559]
#  [1509721260.0 1509721260 Timestamp('2017-11-03 15:01:00') ..., 300 300
#   6527]
#  [1509721320.0 1509721320 Timestamp('2017-11-03 15:02:00') ..., 300 300
#   15578]
#  ...,
#  [1512254940.0 1512254940 Timestamp('2017-12-02 22:49:00') ..., 280 280
#   7209]
#  [1512255000.0 1512255000 Timestamp('2017-12-02 22:50:00') ..., 320 320
#   7244]
#  [1512255060.0 1512255060 Timestamp('2017-12-02 22:51:00') ..., 300 300
#   7155]]
# (42114, 55)

# %%
output_df = pd.DataFrame(output_arr)

output_df.columns = ['UNIX_time','useless', 'timestamp','cpu_usage', 'max_cpu_usage', 'free_memory', 'min_free_memory', 'total_memory', 'use_memory_rate', 'stat_value_1', 'stat_value_2', 'stat_value_3', 'stat_value_4', 'stat_value_5', 'stat_value_6', 'stat_value_7', 'stat_value_8', 'stat_value_9', 'stat_value_10', 'stat_value_11', 'stat_value_12', 'stat_value_13', 'stat_value_14', 'stat_value_15', 'stat_value_16', 'stat_value_17', 'stat_value_18', 'stat_value_19', 'stat_value_20', 'stat_value_21', 'stat_value_22', 'stat_value_23', 'stat_value_24', 'stat_value_25', 'stat_value_26', 'stat_value_27', 'stat_value_28', 'stat_value_29', 'stat_value_30', 'stat_value_31', 'stat_value_32', 'stat_value_33', 'stat_value_34', 'wait_event_1', 'wait_event_2','wait_event_3','wait_event_4','wait_event_5','wait_event_6','wait_event_7','wait_event_8','wait_event_9','wait_event_10','wait_event_11', 'Y_next_wait_sum']
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
output_df.to_gbq('ods_im5.train_1_im5_os_stat_wait', 'exem-191100', if_exists = 'replace', chunksize = 2000)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# Streaming Insert is 4% Complete
# Streaming Insert is 9% Complete
# Streaming Insert is 14% Complete
# Streaming Insert is 18% Complete
# Streaming Insert is 23% Complete
# Streaming Insert is 28% Complete
# Streaming Insert is 33% Complete
# Streaming Insert is 37% Complete
# Streaming Insert is 42% Complete
# Streaming Insert is 47% Complete
# Streaming Insert is 52% Complete
# Streaming Insert is 56% Complete
# Streaming Insert is 61% Complete
# Streaming Insert is 66% Complete
# Streaming Insert is 71% Complete
# Streaming Insert is 75% Complete
# Streaming Insert is 80% Complete
# Streaming Insert is 85% Complete
# Streaming Insert is 90% Complete
# Streaming Insert is 94% Complete
# Streaming Insert is 99% Complete
# Streaming Insert is 100% Complete

# %%
# %%bq query --name train_1
# SELECT *
# FROM `exem-191100.ods_im5.train_1_im5_os_stat_wait`
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
# %%bq sample --query train_1 --count 100
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# QueryResultsTable job_lV8mg25yJo8uOUy2zVo2q-s-fBsJ

# %%
test_arr = [[]]
temp_arr = [join1_arr[0]]
temp_arr = np.append(temp_arr, [[wait_arr[(0)*11+0][3]]], axis=1)

test_arr = temp_arr
test_arr = np.append(test_arr, temp_arr, axis = 0)
test_arr = np.append(test_arr, temp_arr, axis = 0)
print(test_arr)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [['1509952980' '2017-11-06T07:23:00Z' '5084' '5330' '280312' '276128'
#   '6117496' '0.9541786378' '36' '56' '883985' '159' '23' '1672526'
#   '1683315' '839' '54248646' '0' '0' '60313' '14' '52428' '-26214' '23'
#   '23' '5' '93388' '4' '54809' '148198' '21' '17' '194969' '0' '265' '12'
#   '3' '0' '23' '36' '13' '36' 300]
#  ['1509952980' '2017-11-06T07:23:00Z' '5084' '5330' '280312' '276128'
#   '6117496' '0.9541786378' '36' '56' '883985' '159' '23' '1672526'
#   '1683315' '839' '54248646' '0' '0' '60313' '14' '52428' '-26214' '23'
#   '23' '5' '93388' '4' '54809' '148198' '21' '17' '194969' '0' '265' '12'
#   '3' '0' '23' '36' '13' '36' 300]
#  ['1509952980' '2017-11-06T07:23:00Z' '5084' '5330' '280312' '276128'
#   '6117496' '0.9541786378' '36' '56' '883985' '159' '23' '1672526'
#   '1683315' '839' '54248646' '0' '0' '60313' '14' '52428' '-26214' '23'
#   '23' '5' '93388' '4' '54809' '148198' '21' '17' '194969' '0' '265' '12'
#   '3' '0' '23' '36' '13' '36' 300]]

# %%
join2_arr = [[]]
emp = 0

# 1512255120 = 2017-12-02 22:52:00

length = (1512255120-1509721200)/60 +1

for i in range(join1_arr.shape[0]):
  
  wait_time = wait_arr[i-emp][0]
  time = join1_arr[i][0]
  
  if(time == wait_time):
    if(time == 1509721200):
      result_arr = [join_arr[i-emp]]
    else:  
      result_arr = np.append(result_arr, [join_arr[i-emp]], axis = 0)
  else:
    emp+=1
    result_arr = np.append(result_arr, [join_arr[i-emp]], axis = 0)

# %%
print(join1_arr.shape[0])
print(wait_arr.shape[0]/11)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# 42233
# 44396

# %%
print([join1_arr[0]])
temp_arr = np.append(temp_arr, [[stat_arr[i*34+j][2]]], axis=1)
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# [array(['1509952980', '2017-11-06T07:23:00Z', '5084', '5330', '280312',
#        '276128', '6117496', '0.9541786378', '36', '56', '883985', '159',
#        '23', '1672526', '1683315', '839', '54248646', '0', '0', '60313',
#        '14', '52428', '-26214', '23', '23', '5', '93388', '4', '54809',
#        '148198', '21', '17', '194969', '0', '265', '12', '3', '0', '23',
#        '36', '13', '36'], dtype=object)]
